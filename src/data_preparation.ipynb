# %%
## データセットemotional_persuasive_dialogueを整形してデータベースに格納する
## このセルは1回実行しておくだけでOK

import random
import sqlite3
from pathlib import Path
import time

def select_label(mode, label_options):
    """
    受諾度合い、感情ラベルで、3つ中2つ以上一致している
    ラベルをその発話のラベルとして採用する
    """
    
    # ラベル候補のリストからランダムに3つ要素を取得する
    label_options = random.sample(label_options.split("-"), 3)
    # 改行文字を取り除く
    # 感情状態ラベルの末尾には「,」が付いていて、改行文字が末尾に来ない
    # 受諾度合いラベルの末尾には「,」が付いていないため、改行文字が末尾に来てしまう
    # 改行文字を除去しないと、ラベルの付与数を正常にcountできない
    for i in range(len(label_options)):
        label_options[i] = label_options[i].strip()
    
    # 感情ラベルと受諾度合いラベルのパターン
    emotions = ["平静", "安心", "喜び", "怒り", "悲しみ"]
    acceptances = [str(i) for i in range(1, 6)]
    
    # 各ラベルが何個付与されているかを数えて、辞書として記録する
    count_dict = {}
    if mode == "system_emotion" or mode == "user_emotion":
        for x in emotions:
            count_dict[x] = label_options.count(x)
    elif mode == "user_acceptance":
        for x in acceptances:
            count_dict[x] = label_options.count(x)
    
    # 2個以上付与されているラベルが何なのかを求める
    # 2つ以上同じラベルが付与されていたら、リストの要素は必ず1つになる
    # 1つずつ違うラベルが付与されていたら、resultは空になる
    result = [k for k, v in count_dict.items() if v >= 2]
    if result != []:
        return result[0]
    else:
        return "NONE"

def data_preperation():
    """
    データセットをデータベースに登録する。
    受諾度合いラベルと感情状態ラベルは、1発話に付与されているもの先頭3個を使う。
    その3個のうち2個以上同じものがあれば、その発話のラベルとして採用する。
    1つも同じものが無ければ、NONEを付与する。
    データベースに登録はするが、実際の学習では、NONEが付与されたものは除去する。
    """
    
    origin_path = "../emotional_persuasive_dialogue/"
    # データセットを格納するデータベース
    db = sqlite3.connect("dialogue_corpus.db")
    c = db.cursor()
    
    for scene in ["cleaning", "exercise", "game", "lunch", "sleep"]:
        for i in range(0, 200):
            # 5場面 * 200対話
            # Pathオブジェクト
            path = Path(origin_path + scene + "/" + str(i) + ".txt.label")
            
            # executeメソッドでSQL文を実行する
            # カラム：talker | talk_content | acceptance | emotion
            table_name = scene + str(i)
            create_table = "create table " + table_name + " (talker text, talk_content text, emotion text, acceptance text)"
            c.execute(create_table)
            
            with path.open('r', encoding='utf-8') as file:
                for line in file:
                    # データセットから話者などの情報を取得する
                    columns = line.split(",") # 例：['ロボット1', 'Ａ君、お部屋を掃除をしましょう。', '平静-平静-安心-怒り', '\n']
                    talker, talk_content, emotion, acceptance = "", "", "", ""
                    if columns[0].find("ロボット") != -1:
                        # システムの発話を読み込んでいる時
                        talker, talk_content, emotion, acceptance = "system", columns[1], select_label("system_emotion", columns[2]), "-"
                    elif columns[0].find("A君") != -1:
                        # ユーザの発話を読み込んでいる時
                        talker, talk_content, emotion, acceptance = "user", columns[1], select_label("user_emotion", columns[2]), select_label("user_acceptance", columns[3])
                    
                    # SQL文に値をセットする場合は，Pythonのformatメソッドなどは使わずに，
                    # セットしたい場所に?を記述し，executeメソッドの第2引数に?に当てはめる値を
                    # タプルで渡す．
                    sql = "insert into " + table_name + " (talker, talk_content, emotion, acceptance) values (?, ?, ?, ?)"
                    data = (talker, talk_content, emotion, acceptance)
                    c.execute(sql, data)

                    db.commit()
            print("Table:{} has been registered.".format(table_name))
        print("Scene:{} has been registered.".format(scene))
    db.close()
    print("dialogue_corpus.db has been structed completely.")

before_time = time.time()
data_preperation()
after_time = time.time()
print("By time.time(): data_preperation took about {} seconds.".format(after_time - before_time))
# Out:
# Table:cleaning0 has been registered.
# Table:cleaning1 has been registered.
# Table:cleaning2 has been registered.
# Table:cleaning3 has been registered.
# Table:cleaning4 has been registered.
# Table:cleaning5 has been registered.
# Table:cleaning6 has been registered.
# Table:cleaning7 has been registered.
# Table:cleaning8 has been registered.
# Table:cleaning9 has been registered.
# Table:cleaning10 has been registered.
# Table:cleaning11 has been registered.
# Table:cleaning12 has been registered.
# Table:cleaning13 has been registered.
# Table:cleaning14 has been registered.
# Table:cleaning15 has been registered.
# Table:cleaning16 has been registered.
# Table:cleaning17 has been registered.
# Table:cleaning18 has been registered.
# Table:cleaning19 has been registered.
# Table:cleaning20 has been registered.
# Table:cleaning21 has been registered.
# Table:cleaning22 has been registered.
# Table:cleaning23 has been registered.
# Table:cleaning24 has been registered.
# Table:cleaning25 has been registered.
# Table:cleaning26 has been registered.
# Table:cleaning27 has been registered.
# Table:cleaning28 has been registered.
# Table:cleaning29 has been registered.
# Table:cleaning30 has been registered.
# Table:cleaning31 has been registered.
# Table:cleaning32 has been registered.
# Table:cleaning33 has been registered.
# Table:cleaning34 has been registered.
# Table:cleaning35 has been registered.
# Table:cleaning36 has been registered.
# Table:cleaning37 has been registered.
# Table:cleaning38 has been registered.
# Table:cleaning39 has been registered.
# Table:cleaning40 has been registered.
# Table:cleaning41 has been registered.
# Table:cleaning42 has been registered.
# Table:cleaning43 has been registered.
# Table:cleaning44 has been registered.
# Table:cleaning45 has been registered.
# Table:cleaning46 has been registered.
# Table:cleaning47 has been registered.
# Table:cleaning48 has been registered.
# Table:cleaning49 has been registered.
# Table:cleaning50 has been registered.
# Table:cleaning51 has been registered.
# Table:cleaning52 has been registered.
# Table:cleaning53 has been registered.
# Table:cleaning54 has been registered.
# Table:cleaning55 has been registered.
# Table:cleaning56 has been registered.
# Table:cleaning57 has been registered.
# Table:cleaning58 has been registered.
# Table:cleaning59 has been registered.
# Table:cleaning60 has been registered.
# Table:cleaning61 has been registered.
# Table:cleaning62 has been registered.
# Table:cleaning63 has been registered.
# Table:cleaning64 has been registered.
# Table:cleaning65 has been registered.
# Table:cleaning66 has been registered.
# Table:cleaning67 has been registered.
# Table:cleaning68 has been registered.
# Table:cleaning69 has been registered.
# Table:cleaning70 has been registered.
# Table:cleaning71 has been registered.
# Table:cleaning72 has been registered.
# Table:cleaning73 has been registered.
# Table:cleaning74 has been registered.
# Table:cleaning75 has been registered.
# Table:cleaning76 has been registered.
# Table:cleaning77 has been registered.
# Table:cleaning78 has been registered.
# Table:cleaning79 has been registered.
# Table:cleaning80 has been registered.
# Table:cleaning81 has been registered.
# Table:cleaning82 has been registered.
# Table:cleaning83 has been registered.
# Table:cleaning84 has been registered.
# Table:cleaning85 has been registered.
# Table:cleaning86 has been registered.
# Table:cleaning87 has been registered.
# Table:cleaning88 has been registered.
# Table:cleaning89 has been registered.
# Table:cleaning90 has been registered.
# Table:cleaning91 has been registered.
# Table:cleaning92 has been registered.
# Table:cleaning93 has been registered.
# Table:cleaning94 has been registered.
# Table:cleaning95 has been registered.
# Table:cleaning96 has been registered.
# Table:cleaning97 has been registered.
# Table:cleaning98 has been registered.
# Table:cleaning99 has been registered.
# Table:cleaning100 has been registered.
# Table:cleaning101 has been registered.
# Table:cleaning102 has been registered.
# Table:cleaning103 has been registered.
# Table:cleaning104 has been registered.
# Table:cleaning105 has been registered.
# Table:cleaning106 has been registered.
# Table:cleaning107 has been registered.
# Table:cleaning108 has been registered.
# Table:cleaning109 has been registered.
# Table:cleaning110 has been registered.
# Table:cleaning111 has been registered.
# Table:cleaning112 has been registered.
# Table:cleaning113 has been registered.
# Table:cleaning114 has been registered.
# Table:cleaning115 has been registered.
# Table:cleaning116 has been registered.
# Table:cleaning117 has been registered.
# Table:cleaning118 has been registered.
# Table:cleaning119 has been registered.
# Table:cleaning120 has been registered.
# Table:cleaning121 has been registered.
# Table:cleaning122 has been registered.
# Table:cleaning123 has been registered.
# Table:cleaning124 has been registered.
# Table:cleaning125 has been registered.
# Table:cleaning126 has been registered.
# Table:cleaning127 has been registered.
# Table:cleaning128 has been registered.
# Table:cleaning129 has been registered.
# Table:cleaning130 has been registered.
# Table:cleaning131 has been registered.
# Table:cleaning132 has been registered.
# Table:cleaning133 has been registered.
# Table:cleaning134 has been registered.
# Table:cleaning135 has been registered.
# Table:cleaning136 has been registered.
# Table:cleaning137 has been registered.
# Table:cleaning138 has been registered.
# Table:cleaning139 has been registered.
# Table:cleaning140 has been registered.
# Table:cleaning141 has been registered.
# Table:cleaning142 has been registered.
# Table:cleaning143 has been registered.
# Table:cleaning144 has been registered.
# Table:cleaning145 has been registered.
# Table:cleaning146 has been registered.
# Table:cleaning147 has been registered.
# Table:cleaning148 has been registered.
# Table:cleaning149 has been registered.
# Table:cleaning150 has been registered.
# Table:cleaning151 has been registered.
# Table:cleaning152 has been registered.
# Table:cleaning153 has been registered.
# Table:cleaning154 has been registered.
# Table:cleaning155 has been registered.
# Table:cleaning156 has been registered.
# Table:cleaning157 has been registered.
# Table:cleaning158 has been registered.
# Table:cleaning159 has been registered.
# Table:cleaning160 has been registered.
# Table:cleaning161 has been registered.
# Table:cleaning162 has been registered.
# Table:cleaning163 has been registered.
# Table:cleaning164 has been registered.
# Table:cleaning165 has been registered.
# Table:cleaning166 has been registered.
# Table:cleaning167 has been registered.
# Table:cleaning168 has been registered.
# Table:cleaning169 has been registered.
# Table:cleaning170 has been registered.
# Table:cleaning171 has been registered.
# Table:cleaning172 has been registered.
# Table:cleaning173 has been registered.
# Table:cleaning174 has been registered.
# Table:cleaning175 has been registered.
# Table:cleaning176 has been registered.
# Table:cleaning177 has been registered.
# Table:cleaning178 has been registered.
# Table:cleaning179 has been registered.
# Table:cleaning180 has been registered.
# Table:cleaning181 has been registered.
# Table:cleaning182 has been registered.
# Table:cleaning183 has been registered.
# Table:cleaning184 has been registered.
# Table:cleaning185 has been registered.
# Table:cleaning186 has been registered.
# Table:cleaning187 has been registered.
# Table:cleaning188 has been registered.
# Table:cleaning189 has been registered.
# Table:cleaning190 has been registered.
# Table:cleaning191 has been registered.
# Table:cleaning192 has been registered.
# Table:cleaning193 has been registered.
# Table:cleaning194 has been registered.
# Table:cleaning195 has been registered.
# Table:cleaning196 has been registered.
# Table:cleaning197 has been registered.
# Table:cleaning198 has been registered.
# Table:cleaning199 has been registered.
# Scene:cleaning has been registered.
# Table:exercise0 has been registered.
# Table:exercise1 has been registered.
# Table:exercise2 has been registered.
# Table:exercise3 has been registered.
# Table:exercise4 has been registered.
# Table:exercise5 has been registered.
# Table:exercise6 has been registered.
# Table:exercise7 has been registered.
# Table:exercise8 has been registered.
# Table:exercise9 has been registered.
# Table:exercise10 has been registered.
# Table:exercise11 has been registered.
# Table:exercise12 has been registered.
# Table:exercise13 has been registered.
# Table:exercise14 has been registered.
# Table:exercise15 has been registered.
# Table:exercise16 has been registered.
# Table:exercise17 has been registered.
# Table:exercise18 has been registered.
# Table:exercise19 has been registered.
# Table:exercise20 has been registered.
# Table:exercise21 has been registered.
# Table:exercise22 has been registered.
# Table:exercise23 has been registered.
# Table:exercise24 has been registered.
# Table:exercise25 has been registered.
# Table:exercise26 has been registered.
# Table:exercise27 has been registered.
# Table:exercise28 has been registered.
# Table:exercise29 has been registered.
# Table:exercise30 has been registered.
# Table:exercise31 has been registered.
# Table:exercise32 has been registered.
# Table:exercise33 has been registered.
# Table:exercise34 has been registered.
# Table:exercise35 has been registered.
# Table:exercise36 has been registered.
# Table:exercise37 has been registered.
# Table:exercise38 has been registered.
# Table:exercise39 has been registered.
# Table:exercise40 has been registered.
# Table:exercise41 has been registered.
# Table:exercise42 has been registered.
# Table:exercise43 has been registered.
# Table:exercise44 has been registered.
# Table:exercise45 has been registered.
# Table:exercise46 has been registered.
# Table:exercise47 has been registered.
# Table:exercise48 has been registered.
# Table:exercise49 has been registered.
# Table:exercise50 has been registered.
# Table:exercise51 has been registered.
# Table:exercise52 has been registered.
# Table:exercise53 has been registered.
# Table:exercise54 has been registered.
# Table:exercise55 has been registered.
# Table:exercise56 has been registered.
# Table:exercise57 has been registered.
# Table:exercise58 has been registered.
# Table:exercise59 has been registered.
# Table:exercise60 has been registered.
# Table:exercise61 has been registered.
# Table:exercise62 has been registered.
# Table:exercise63 has been registered.
# Table:exercise64 has been registered.
# Table:exercise65 has been registered.
# Table:exercise66 has been registered.
# Table:exercise67 has been registered.
# Table:exercise68 has been registered.
# Table:exercise69 has been registered.
# Table:exercise70 has been registered.
# Table:exercise71 has been registered.
# Table:exercise72 has been registered.
# Table:exercise73 has been registered.
# Table:exercise74 has been registered.
# Table:exercise75 has been registered.
# Table:exercise76 has been registered.
# Table:exercise77 has been registered.
# Table:exercise78 has been registered.
# Table:exercise79 has been registered.
# Table:exercise80 has been registered.
# Table:exercise81 has been registered.
# Table:exercise82 has been registered.
# Table:exercise83 has been registered.
# Table:exercise84 has been registered.
# Table:exercise85 has been registered.
# Table:exercise86 has been registered.
# Table:exercise87 has been registered.
# Table:exercise88 has been registered.
# Table:exercise89 has been registered.
# Table:exercise90 has been registered.
# Table:exercise91 has been registered.
# Table:exercise92 has been registered.
# Table:exercise93 has been registered.
# Table:exercise94 has been registered.
# Table:exercise95 has been registered.
# Table:exercise96 has been registered.
# Table:exercise97 has been registered.
# Table:exercise98 has been registered.
# Table:exercise99 has been registered.
# Table:exercise100 has been registered.
# Table:exercise101 has been registered.
# Table:exercise102 has been registered.
# Table:exercise103 has been registered.
# Table:exercise104 has been registered.
# Table:exercise105 has been registered.
# Table:exercise106 has been registered.
# Table:exercise107 has been registered.
# Table:exercise108 has been registered.
# Table:exercise109 has been registered.
# Table:exercise110 has been registered.
# Table:exercise111 has been registered.
# Table:exercise112 has been registered.
# Table:exercise113 has been registered.
# Table:exercise114 has been registered.
# Table:exercise115 has been registered.
# Table:exercise116 has been registered.
# Table:exercise117 has been registered.
# Table:exercise118 has been registered.
# Table:exercise119 has been registered.
# Table:exercise120 has been registered.
# Table:exercise121 has been registered.
# Table:exercise122 has been registered.
# Table:exercise123 has been registered.
# Table:exercise124 has been registered.
# Table:exercise125 has been registered.
# Table:exercise126 has been registered.
# Table:exercise127 has been registered.
# Table:exercise128 has been registered.
# Table:exercise129 has been registered.
# Table:exercise130 has been registered.
# Table:exercise131 has been registered.
# Table:exercise132 has been registered.
# Table:exercise133 has been registered.
# Table:exercise134 has been registered.
# Table:exercise135 has been registered.
# Table:exercise136 has been registered.
# Table:exercise137 has been registered.
# Table:exercise138 has been registered.
# Table:exercise139 has been registered.
# Table:exercise140 has been registered.
# Table:exercise141 has been registered.
# Table:exercise142 has been registered.
# Table:exercise143 has been registered.
# Table:exercise144 has been registered.
# Table:exercise145 has been registered.
# Table:exercise146 has been registered.
# Table:exercise147 has been registered.
# Table:exercise148 has been registered.
# Table:exercise149 has been registered.
# Table:exercise150 has been registered.
# Table:exercise151 has been registered.
# Table:exercise152 has been registered.
# Table:exercise153 has been registered.
# Table:exercise154 has been registered.
# Table:exercise155 has been registered.
# Table:exercise156 has been registered.
# Table:exercise157 has been registered.
# Table:exercise158 has been registered.
# Table:exercise159 has been registered.
# Table:exercise160 has been registered.
# Table:exercise161 has been registered.
# Table:exercise162 has been registered.
# Table:exercise163 has been registered.
# Table:exercise164 has been registered.
# Table:exercise165 has been registered.
# Table:exercise166 has been registered.
# Table:exercise167 has been registered.
# Table:exercise168 has been registered.
# Table:exercise169 has been registered.
# Table:exercise170 has been registered.
# Table:exercise171 has been registered.
# Table:exercise172 has been registered.
# Table:exercise173 has been registered.
# Table:exercise174 has been registered.
# Table:exercise175 has been registered.
# Table:exercise176 has been registered.
# Table:exercise177 has been registered.
# Table:exercise178 has been registered.
# Table:exercise179 has been registered.
# Table:exercise180 has been registered.
# Table:exercise181 has been registered.
# Table:exercise182 has been registered.
# Table:exercise183 has been registered.
# Table:exercise184 has been registered.
# Table:exercise185 has been registered.
# Table:exercise186 has been registered.
# Table:exercise187 has been registered.
# Table:exercise188 has been registered.
# Table:exercise189 has been registered.
# Table:exercise190 has been registered.
# Table:exercise191 has been registered.
# Table:exercise192 has been registered.
# Table:exercise193 has been registered.
# Table:exercise194 has been registered.
# Table:exercise195 has been registered.
# Table:exercise196 has been registered.
# Table:exercise197 has been registered.
# Table:exercise198 has been registered.
# Table:exercise199 has been registered.
# Scene:exercise has been registered.
# Table:game0 has been registered.
# Table:game1 has been registered.
# Table:game2 has been registered.
# Table:game3 has been registered.
# Table:game4 has been registered.
# Table:game5 has been registered.
# Table:game6 has been registered.
# Table:game7 has been registered.
# Table:game8 has been registered.
# Table:game9 has been registered.
# Table:game10 has been registered.
# Table:game11 has been registered.
# Table:game12 has been registered.
# Table:game13 has been registered.
# Table:game14 has been registered.
# Table:game15 has been registered.
# Table:game16 has been registered.
# Table:game17 has been registered.
# Table:game18 has been registered.
# Table:game19 has been registered.
# Table:game20 has been registered.
# Table:game21 has been registered.
# Table:game22 has been registered.
# Table:game23 has been registered.
# Table:game24 has been registered.
# Table:game25 has been registered.
# Table:game26 has been registered.
# Table:game27 has been registered.
# Table:game28 has been registered.
# Table:game29 has been registered.
# Table:game30 has been registered.
# Table:game31 has been registered.
# Table:game32 has been registered.
# Table:game33 has been registered.
# Table:game34 has been registered.
# Table:game35 has been registered.
# Table:game36 has been registered.
# Table:game37 has been registered.
# Table:game38 has been registered.
# Table:game39 has been registered.
# Table:game40 has been registered.
# Table:game41 has been registered.
# Table:game42 has been registered.
# Table:game43 has been registered.
# Table:game44 has been registered.
# Table:game45 has been registered.
# Table:game46 has been registered.
# Table:game47 has been registered.
# Table:game48 has been registered.
# Table:game49 has been registered.
# Table:game50 has been registered.
# Table:game51 has been registered.
# Table:game52 has been registered.
# Table:game53 has been registered.
# Table:game54 has been registered.
# Table:game55 has been registered.
# Table:game56 has been registered.
# Table:game57 has been registered.
# Table:game58 has been registered.
# Table:game59 has been registered.
# Table:game60 has been registered.
# Table:game61 has been registered.
# Table:game62 has been registered.
# Table:game63 has been registered.
# Table:game64 has been registered.
# Table:game65 has been registered.
# Table:game66 has been registered.
# Table:game67 has been registered.
# Table:game68 has been registered.
# Table:game69 has been registered.
# Table:game70 has been registered.
# Table:game71 has been registered.
# Table:game72 has been registered.
# Table:game73 has been registered.
# Table:game74 has been registered.
# Table:game75 has been registered.
# Table:game76 has been registered.
# Table:game77 has been registered.
# Table:game78 has been registered.
# Table:game79 has been registered.
# Table:game80 has been registered.
# Table:game81 has been registered.
# Table:game82 has been registered.
# Table:game83 has been registered.
# Table:game84 has been registered.
# Table:game85 has been registered.
# Table:game86 has been registered.
# Table:game87 has been registered.
# Table:game88 has been registered.
# Table:game89 has been registered.
# Table:game90 has been registered.
# Table:game91 has been registered.
# Table:game92 has been registered.
# Table:game93 has been registered.
# Table:game94 has been registered.
# Table:game95 has been registered.
# Table:game96 has been registered.
# Table:game97 has been registered.
# Table:game98 has been registered.
# Table:game99 has been registered.
# Table:game100 has been registered.
# Table:game101 has been registered.
# Table:game102 has been registered.
# Table:game103 has been registered.
# Table:game104 has been registered.
# Table:game105 has been registered.
# Table:game106 has been registered.
# Table:game107 has been registered.
# Table:game108 has been registered.
# Table:game109 has been registered.
# Table:game110 has been registered.
# Table:game111 has been registered.
# Table:game112 has been registered.
# Table:game113 has been registered.
# Table:game114 has been registered.
# Table:game115 has been registered.
# Table:game116 has been registered.
# Table:game117 has been registered.
# Table:game118 has been registered.
# Table:game119 has been registered.
# Table:game120 has been registered.
# Table:game121 has been registered.
# Table:game122 has been registered.
# Table:game123 has been registered.
# Table:game124 has been registered.
# Table:game125 has been registered.
# Table:game126 has been registered.
# Table:game127 has been registered.
# Table:game128 has been registered.
# Table:game129 has been registered.
# Table:game130 has been registered.
# Table:game131 has been registered.
# Table:game132 has been registered.
# Table:game133 has been registered.
# Table:game134 has been registered.
# Table:game135 has been registered.
# Table:game136 has been registered.
# Table:game137 has been registered.
# Table:game138 has been registered.
# Table:game139 has been registered.
# Table:game140 has been registered.
# Table:game141 has been registered.
# Table:game142 has been registered.
# Table:game143 has been registered.
# Table:game144 has been registered.
# Table:game145 has been registered.
# Table:game146 has been registered.
# Table:game147 has been registered.
# Table:game148 has been registered.
# Table:game149 has been registered.
# Table:game150 has been registered.
# Table:game151 has been registered.
# Table:game152 has been registered.
# Table:game153 has been registered.
# Table:game154 has been registered.
# Table:game155 has been registered.
# Table:game156 has been registered.
# Table:game157 has been registered.
# Table:game158 has been registered.
# Table:game159 has been registered.
# Table:game160 has been registered.
# Table:game161 has been registered.
# Table:game162 has been registered.
# Table:game163 has been registered.
# Table:game164 has been registered.
# Table:game165 has been registered.
# Table:game166 has been registered.
# Table:game167 has been registered.
# Table:game168 has been registered.
# Table:game169 has been registered.
# Table:game170 has been registered.
# Table:game171 has been registered.
# Table:game172 has been registered.
# Table:game173 has been registered.
# Table:game174 has been registered.
# Table:game175 has been registered.
# Table:game176 has been registered.
# Table:game177 has been registered.
# Table:game178 has been registered.
# Table:game179 has been registered.
# Table:game180 has been registered.
# Table:game181 has been registered.
# Table:game182 has been registered.
# Table:game183 has been registered.
# Table:game184 has been registered.
# Table:game185 has been registered.
# Table:game186 has been registered.
# Table:game187 has been registered.
# Table:game188 has been registered.
# Table:game189 has been registered.
# Table:game190 has been registered.
# Table:game191 has been registered.
# Table:game192 has been registered.
# Table:game193 has been registered.
# Table:game194 has been registered.
# Table:game195 has been registered.
# Table:game196 has been registered.
# Table:game197 has been registered.
# Table:game198 has been registered.
# Table:game199 has been registered.
# Scene:game has been registered.
# Table:lunch0 has been registered.
# Table:lunch1 has been registered.
# Table:lunch2 has been registered.
# Table:lunch3 has been registered.
# Table:lunch4 has been registered.
# Table:lunch5 has been registered.
# Table:lunch6 has been registered.
# Table:lunch7 has been registered.
# Table:lunch8 has been registered.
# Table:lunch9 has been registered.
# Table:lunch10 has been registered.
# Table:lunch11 has been registered.
# Table:lunch12 has been registered.
# Table:lunch13 has been registered.
# Table:lunch14 has been registered.
# Table:lunch15 has been registered.
# Table:lunch16 has been registered.
# Table:lunch17 has been registered.
# Table:lunch18 has been registered.
# Table:lunch19 has been registered.
# Table:lunch20 has been registered.
# Table:lunch21 has been registered.
# Table:lunch22 has been registered.
# Table:lunch23 has been registered.
# Table:lunch24 has been registered.
# Table:lunch25 has been registered.
# Table:lunch26 has been registered.
# Table:lunch27 has been registered.
# Table:lunch28 has been registered.
# Table:lunch29 has been registered.
# Table:lunch30 has been registered.
# Table:lunch31 has been registered.
# Table:lunch32 has been registered.
# Table:lunch33 has been registered.
# Table:lunch34 has been registered.
# Table:lunch35 has been registered.
# Table:lunch36 has been registered.
# Table:lunch37 has been registered.
# Table:lunch38 has been registered.
# Table:lunch39 has been registered.
# Table:lunch40 has been registered.
# Table:lunch41 has been registered.
# Table:lunch42 has been registered.
# Table:lunch43 has been registered.
# Table:lunch44 has been registered.
# Table:lunch45 has been registered.
# Table:lunch46 has been registered.
# Table:lunch47 has been registered.
# Table:lunch48 has been registered.
# Table:lunch49 has been registered.
# Table:lunch50 has been registered.
# Table:lunch51 has been registered.
# Table:lunch52 has been registered.
# Table:lunch53 has been registered.
# Table:lunch54 has been registered.
# Table:lunch55 has been registered.
# Table:lunch56 has been registered.
# Table:lunch57 has been registered.
# Table:lunch58 has been registered.
# Table:lunch59 has been registered.
# Table:lunch60 has been registered.
# Table:lunch61 has been registered.
# Table:lunch62 has been registered.
# Table:lunch63 has been registered.
# Table:lunch64 has been registered.
# Table:lunch65 has been registered.
# Table:lunch66 has been registered.
# Table:lunch67 has been registered.
# Table:lunch68 has been registered.
# Table:lunch69 has been registered.
# Table:lunch70 has been registered.
# Table:lunch71 has been registered.
# Table:lunch72 has been registered.
# Table:lunch73 has been registered.
# Table:lunch74 has been registered.
# Table:lunch75 has been registered.
# Table:lunch76 has been registered.
# Table:lunch77 has been registered.
# Table:lunch78 has been registered.
# Table:lunch79 has been registered.
# Table:lunch80 has been registered.
# Table:lunch81 has been registered.
# Table:lunch82 has been registered.
# Table:lunch83 has been registered.
# Table:lunch84 has been registered.
# Table:lunch85 has been registered.
# Table:lunch86 has been registered.
# Table:lunch87 has been registered.
# Table:lunch88 has been registered.
# Table:lunch89 has been registered.
# Table:lunch90 has been registered.
# Table:lunch91 has been registered.
# Table:lunch92 has been registered.
# Table:lunch93 has been registered.
# Table:lunch94 has been registered.
# Table:lunch95 has been registered.
# Table:lunch96 has been registered.
# Table:lunch97 has been registered.
# Table:lunch98 has been registered.
# Table:lunch99 has been registered.
# Table:lunch100 has been registered.
# Table:lunch101 has been registered.
# Table:lunch102 has been registered.
# Table:lunch103 has been registered.
# Table:lunch104 has been registered.
# Table:lunch105 has been registered.
# Table:lunch106 has been registered.
# Table:lunch107 has been registered.
# Table:lunch108 has been registered.
# Table:lunch109 has been registered.
# Table:lunch110 has been registered.
# Table:lunch111 has been registered.
# Table:lunch112 has been registered.
# Table:lunch113 has been registered.
# Table:lunch114 has been registered.
# Table:lunch115 has been registered.
# Table:lunch116 has been registered.
# Table:lunch117 has been registered.
# Table:lunch118 has been registered.
# Table:lunch119 has been registered.
# Table:lunch120 has been registered.
# Table:lunch121 has been registered.
# Table:lunch122 has been registered.
# Table:lunch123 has been registered.
# Table:lunch124 has been registered.
# Table:lunch125 has been registered.
# Table:lunch126 has been registered.
# Table:lunch127 has been registered.
# Table:lunch128 has been registered.
# Table:lunch129 has been registered.
# Table:lunch130 has been registered.
# Table:lunch131 has been registered.
# Table:lunch132 has been registered.
# Table:lunch133 has been registered.
# Table:lunch134 has been registered.
# Table:lunch135 has been registered.
# Table:lunch136 has been registered.
# Table:lunch137 has been registered.
# Table:lunch138 has been registered.
# Table:lunch139 has been registered.
# Table:lunch140 has been registered.
# Table:lunch141 has been registered.
# Table:lunch142 has been registered.
# Table:lunch143 has been registered.
# Table:lunch144 has been registered.
# Table:lunch145 has been registered.
# Table:lunch146 has been registered.
# Table:lunch147 has been registered.
# Table:lunch148 has been registered.
# Table:lunch149 has been registered.
# Table:lunch150 has been registered.
# Table:lunch151 has been registered.
# Table:lunch152 has been registered.
# Table:lunch153 has been registered.
# Table:lunch154 has been registered.
# Table:lunch155 has been registered.
# Table:lunch156 has been registered.
# Table:lunch157 has been registered.
# Table:lunch158 has been registered.
# Table:lunch159 has been registered.
# Table:lunch160 has been registered.
# Table:lunch161 has been registered.
# Table:lunch162 has been registered.
# Table:lunch163 has been registered.
# Table:lunch164 has been registered.
# Table:lunch165 has been registered.
# Table:lunch166 has been registered.
# Table:lunch167 has been registered.
# Table:lunch168 has been registered.
# Table:lunch169 has been registered.
# Table:lunch170 has been registered.
# Table:lunch171 has been registered.
# Table:lunch172 has been registered.
# Table:lunch173 has been registered.
# Table:lunch174 has been registered.
# Table:lunch175 has been registered.
# Table:lunch176 has been registered.
# Table:lunch177 has been registered.
# Table:lunch178 has been registered.
# Table:lunch179 has been registered.
# Table:lunch180 has been registered.
# Table:lunch181 has been registered.
# Table:lunch182 has been registered.
# Table:lunch183 has been registered.
# Table:lunch184 has been registered.
# Table:lunch185 has been registered.
# Table:lunch186 has been registered.
# Table:lunch187 has been registered.
# Table:lunch188 has been registered.
# Table:lunch189 has been registered.
# Table:lunch190 has been registered.
# Table:lunch191 has been registered.
# Table:lunch192 has been registered.
# Table:lunch193 has been registered.
# Table:lunch194 has been registered.
# Table:lunch195 has been registered.
# Table:lunch196 has been registered.
# Table:lunch197 has been registered.
# Table:lunch198 has been registered.
# Table:lunch199 has been registered.
# Scene:lunch has been registered.
# Table:sleep0 has been registered.
# Table:sleep1 has been registered.
# Table:sleep2 has been registered.
# Table:sleep3 has been registered.
# Table:sleep4 has been registered.
# Table:sleep5 has been registered.
# Table:sleep6 has been registered.
# Table:sleep7 has been registered.
# Table:sleep8 has been registered.
# Table:sleep9 has been registered.
# Table:sleep10 has been registered.
# Table:sleep11 has been registered.
# Table:sleep12 has been registered.
# Table:sleep13 has been registered.
# Table:sleep14 has been registered.
# Table:sleep15 has been registered.
# Table:sleep16 has been registered.
# Table:sleep17 has been registered.
# Table:sleep18 has been registered.
# Table:sleep19 has been registered.
# Table:sleep20 has been registered.
# Table:sleep21 has been registered.
# Table:sleep22 has been registered.
# Table:sleep23 has been registered.
# Table:sleep24 has been registered.
# Table:sleep25 has been registered.
# Table:sleep26 has been registered.
# Table:sleep27 has been registered.
# Table:sleep28 has been registered.
# Table:sleep29 has been registered.
# Table:sleep30 has been registered.
# Table:sleep31 has been registered.
# Table:sleep32 has been registered.
# Table:sleep33 has been registered.
# Table:sleep34 has been registered.
# Table:sleep35 has been registered.
# Table:sleep36 has been registered.
# Table:sleep37 has been registered.
# Table:sleep38 has been registered.
# Table:sleep39 has been registered.
# Table:sleep40 has been registered.
# Table:sleep41 has been registered.
# Table:sleep42 has been registered.
# Table:sleep43 has been registered.
# Table:sleep44 has been registered.
# Table:sleep45 has been registered.
# Table:sleep46 has been registered.
# Table:sleep47 has been registered.
# Table:sleep48 has been registered.
# Table:sleep49 has been registered.
# Table:sleep50 has been registered.
# Table:sleep51 has been registered.
# Table:sleep52 has been registered.
# Table:sleep53 has been registered.
# Table:sleep54 has been registered.
# Table:sleep55 has been registered.
# Table:sleep56 has been registered.
# Table:sleep57 has been registered.
# Table:sleep58 has been registered.
# Table:sleep59 has been registered.
# Table:sleep60 has been registered.
# Table:sleep61 has been registered.
# Table:sleep62 has been registered.
# Table:sleep63 has been registered.
# Table:sleep64 has been registered.
# Table:sleep65 has been registered.
# Table:sleep66 has been registered.
# Table:sleep67 has been registered.
# Table:sleep68 has been registered.
# Table:sleep69 has been registered.
# Table:sleep70 has been registered.
# Table:sleep71 has been registered.
# Table:sleep72 has been registered.
# Table:sleep73 has been registered.
# Table:sleep74 has been registered.
# Table:sleep75 has been registered.
# Table:sleep76 has been registered.
# Table:sleep77 has been registered.
# Table:sleep78 has been registered.
# Table:sleep79 has been registered.
# Table:sleep80 has been registered.
# Table:sleep81 has been registered.
# Table:sleep82 has been registered.
# Table:sleep83 has been registered.
# Table:sleep84 has been registered.
# Table:sleep85 has been registered.
# Table:sleep86 has been registered.
# Table:sleep87 has been registered.
# Table:sleep88 has been registered.
# Table:sleep89 has been registered.
# Table:sleep90 has been registered.
# Table:sleep91 has been registered.
# Table:sleep92 has been registered.
# Table:sleep93 has been registered.
# Table:sleep94 has been registered.
# Table:sleep95 has been registered.
# Table:sleep96 has been registered.
# Table:sleep97 has been registered.
# Table:sleep98 has been registered.
# Table:sleep99 has been registered.
# Table:sleep100 has been registered.
# Table:sleep101 has been registered.
# Table:sleep102 has been registered.
# Table:sleep103 has been registered.
# Table:sleep104 has been registered.
# Table:sleep105 has been registered.
# Table:sleep106 has been registered.
# Table:sleep107 has been registered.
# Table:sleep108 has been registered.
# Table:sleep109 has been registered.
# Table:sleep110 has been registered.
# Table:sleep111 has been registered.
# Table:sleep112 has been registered.
# Table:sleep113 has been registered.
# Table:sleep114 has been registered.
# Table:sleep115 has been registered.
# Table:sleep116 has been registered.
# Table:sleep117 has been registered.
# Table:sleep118 has been registered.
# Table:sleep119 has been registered.
# Table:sleep120 has been registered.
# Table:sleep121 has been registered.
# Table:sleep122 has been registered.
# Table:sleep123 has been registered.
# Table:sleep124 has been registered.
# Table:sleep125 has been registered.
# Table:sleep126 has been registered.
# Table:sleep127 has been registered.
# Table:sleep128 has been registered.
# Table:sleep129 has been registered.
# Table:sleep130 has been registered.
# Table:sleep131 has been registered.
# Table:sleep132 has been registered.
# Table:sleep133 has been registered.
# Table:sleep134 has been registered.
# Table:sleep135 has been registered.
# Table:sleep136 has been registered.
# Table:sleep137 has been registered.
# Table:sleep138 has been registered.
# Table:sleep139 has been registered.
# Table:sleep140 has been registered.
# Table:sleep141 has been registered.
# Table:sleep142 has been registered.
# Table:sleep143 has been registered.
# Table:sleep144 has been registered.
# Table:sleep145 has been registered.
# Table:sleep146 has been registered.
# Table:sleep147 has been registered.
# Table:sleep148 has been registered.
# Table:sleep149 has been registered.
# Table:sleep150 has been registered.
# Table:sleep151 has been registered.
# Table:sleep152 has been registered.
# Table:sleep153 has been registered.
# Table:sleep154 has been registered.
# Table:sleep155 has been registered.
# Table:sleep156 has been registered.
# Table:sleep157 has been registered.
# Table:sleep158 has been registered.
# Table:sleep159 has been registered.
# Table:sleep160 has been registered.
# Table:sleep161 has been registered.
# Table:sleep162 has been registered.
# Table:sleep163 has been registered.
# Table:sleep164 has been registered.
# Table:sleep165 has been registered.
# Table:sleep166 has been registered.
# Table:sleep167 has been registered.
# Table:sleep168 has been registered.
# Table:sleep169 has been registered.
# Table:sleep170 has been registered.
# Table:sleep171 has been registered.
# Table:sleep172 has been registered.
# Table:sleep173 has been registered.
# Table:sleep174 has been registered.
# Table:sleep175 has been registered.
# Table:sleep176 has been registered.
# Table:sleep177 has been registered.
# Table:sleep178 has been registered.
# Table:sleep179 has been registered.
# Table:sleep180 has been registered.
# Table:sleep181 has been registered.
# Table:sleep182 has been registered.
# Table:sleep183 has been registered.
# Table:sleep184 has been registered.
# Table:sleep185 has been registered.
# Table:sleep186 has been registered.
# Table:sleep187 has been registered.
# Table:sleep188 has been registered.
# Table:sleep189 has been registered.
# Table:sleep190 has been registered.
# Table:sleep191 has been registered.
# Table:sleep192 has been registered.
# Table:sleep193 has been registered.
# Table:sleep194 has been registered.
# Table:sleep195 has been registered.
# Table:sleep196 has been registered.
# Table:sleep197 has been registered.
# Table:sleep198 has been registered.
# Table:sleep199 has been registered.
# Scene:sleep has been registered.
# dialogue_corpus.db has been structed completely.
# By time.time(): data_preperation took about 399.34085178375244 seconds.

# %%
import my_data_preparation_kit as my_dpkit

## 1つ下のセルを実行した時は、my_data_preparation_kitの内容をこのファイルに直書きしていた。
## しかし、関数train()を呼び出したら、出力ログが溜まりすぎたせいか、PCがフリーズした。
## -> データの前処理の関数を1つのpythonファイルにまとめる。
## -> 実際の処理は複数のノートブックに分割し、それぞれで上記のpythonファイルをimportして利用する。
## これで出力ログが溜まりすぎるのを防げるはず。

# %%
## word_tableとsynonym_tableを作成してJSON形式で保存する
## このセルは1回実行しておくだけでOK。それ以降はJSONファイルを読み込む

my_dpkit.make_and_save_tables()
# Out:
# Dialogue:cleaning0 has gotten from dialogue_corpus.db.
# Dialogue:cleaning1 has gotten from dialogue_corpus.db.
# Dialogue:cleaning2 has gotten from dialogue_corpus.db.
# Dialogue:cleaning3 has gotten from dialogue_corpus.db.
# Dialogue:cleaning4 has gotten from dialogue_corpus.db.
# Dialogue:cleaning5 has gotten from dialogue_corpus.db.
# Dialogue:cleaning6 has gotten from dialogue_corpus.db.
# Dialogue:cleaning7 has gotten from dialogue_corpus.db.
# Dialogue:cleaning8 has gotten from dialogue_corpus.db.
# Dialogue:cleaning9 has gotten from dialogue_corpus.db.
# Dialogue:cleaning10 has gotten from dialogue_corpus.db.
# Dialogue:cleaning11 has gotten from dialogue_corpus.db.
# Dialogue:cleaning12 has gotten from dialogue_corpus.db.
# Dialogue:cleaning13 has gotten from dialogue_corpus.db.
# Dialogue:cleaning14 has gotten from dialogue_corpus.db.
# Dialogue:cleaning15 has gotten from dialogue_corpus.db.
# Dialogue:cleaning16 has gotten from dialogue_corpus.db.
# Dialogue:cleaning17 has gotten from dialogue_corpus.db.
# Dialogue:cleaning18 has gotten from dialogue_corpus.db.
# Dialogue:cleaning19 has gotten from dialogue_corpus.db.
# Dialogue:cleaning20 has gotten from dialogue_corpus.db.
# Dialogue:cleaning21 has gotten from dialogue_corpus.db.
# Dialogue:cleaning22 has gotten from dialogue_corpus.db.
# Dialogue:cleaning23 has gotten from dialogue_corpus.db.
# Dialogue:cleaning24 has gotten from dialogue_corpus.db.
# Dialogue:cleaning25 has gotten from dialogue_corpus.db.
# Dialogue:cleaning26 has gotten from dialogue_corpus.db.
# Dialogue:cleaning27 has gotten from dialogue_corpus.db.
# Dialogue:cleaning28 has gotten from dialogue_corpus.db.
# Dialogue:cleaning29 has gotten from dialogue_corpus.db.
# Dialogue:cleaning30 has gotten from dialogue_corpus.db.
# Dialogue:cleaning31 has gotten from dialogue_corpus.db.
# Dialogue:cleaning32 has gotten from dialogue_corpus.db.
# Dialogue:cleaning33 has gotten from dialogue_corpus.db.
# Dialogue:cleaning34 has gotten from dialogue_corpus.db.
# Dialogue:cleaning35 has gotten from dialogue_corpus.db.
# Dialogue:cleaning36 has gotten from dialogue_corpus.db.
# Dialogue:cleaning37 has gotten from dialogue_corpus.db.
# Dialogue:cleaning38 has gotten from dialogue_corpus.db.
# Dialogue:cleaning39 has gotten from dialogue_corpus.db.
# Dialogue:cleaning40 has gotten from dialogue_corpus.db.
# Dialogue:cleaning41 has gotten from dialogue_corpus.db.
# Dialogue:cleaning42 has gotten from dialogue_corpus.db.
# Dialogue:cleaning43 has gotten from dialogue_corpus.db.
# Dialogue:cleaning44 has gotten from dialogue_corpus.db.
# Dialogue:cleaning45 has gotten from dialogue_corpus.db.
# Dialogue:cleaning46 has gotten from dialogue_corpus.db.
# Dialogue:cleaning47 has gotten from dialogue_corpus.db.
# Dialogue:cleaning48 has gotten from dialogue_corpus.db.
# Dialogue:cleaning49 has gotten from dialogue_corpus.db.
# Dialogue:cleaning50 has gotten from dialogue_corpus.db.
# Dialogue:cleaning51 has gotten from dialogue_corpus.db.
# Dialogue:cleaning52 has gotten from dialogue_corpus.db.
# Dialogue:cleaning53 has gotten from dialogue_corpus.db.
# Dialogue:cleaning54 has gotten from dialogue_corpus.db.
# Dialogue:cleaning55 has gotten from dialogue_corpus.db.
# Dialogue:cleaning56 has gotten from dialogue_corpus.db.
# Dialogue:cleaning57 has gotten from dialogue_corpus.db.
# Dialogue:cleaning58 has gotten from dialogue_corpus.db.
# Dialogue:cleaning59 has gotten from dialogue_corpus.db.
# Dialogue:cleaning60 has gotten from dialogue_corpus.db.
# Dialogue:cleaning61 has gotten from dialogue_corpus.db.
# Dialogue:cleaning62 has gotten from dialogue_corpus.db.
# Dialogue:cleaning63 has gotten from dialogue_corpus.db.
# Dialogue:cleaning64 has gotten from dialogue_corpus.db.
# Dialogue:cleaning65 has gotten from dialogue_corpus.db.
# Dialogue:cleaning66 has gotten from dialogue_corpus.db.
# Dialogue:cleaning67 has gotten from dialogue_corpus.db.
# Dialogue:cleaning68 has gotten from dialogue_corpus.db.
# Dialogue:cleaning69 has gotten from dialogue_corpus.db.
# Dialogue:cleaning70 has gotten from dialogue_corpus.db.
# Dialogue:cleaning71 has gotten from dialogue_corpus.db.
# Dialogue:cleaning72 has gotten from dialogue_corpus.db.
# Dialogue:cleaning73 has gotten from dialogue_corpus.db.
# Dialogue:cleaning74 has gotten from dialogue_corpus.db.
# Dialogue:cleaning75 has gotten from dialogue_corpus.db.
# Dialogue:cleaning76 has gotten from dialogue_corpus.db.
# Dialogue:cleaning77 has gotten from dialogue_corpus.db.
# Dialogue:cleaning78 has gotten from dialogue_corpus.db.
# Dialogue:cleaning79 has gotten from dialogue_corpus.db.
# Dialogue:cleaning80 has gotten from dialogue_corpus.db.
# Dialogue:cleaning81 has gotten from dialogue_corpus.db.
# Dialogue:cleaning82 has gotten from dialogue_corpus.db.
# Dialogue:cleaning83 has gotten from dialogue_corpus.db.
# Dialogue:cleaning84 has gotten from dialogue_corpus.db.
# Dialogue:cleaning85 has gotten from dialogue_corpus.db.
# Dialogue:cleaning86 has gotten from dialogue_corpus.db.
# Dialogue:cleaning87 has gotten from dialogue_corpus.db.
# Dialogue:cleaning88 has gotten from dialogue_corpus.db.
# Dialogue:cleaning89 has gotten from dialogue_corpus.db.
# Dialogue:cleaning90 has gotten from dialogue_corpus.db.
# Dialogue:cleaning91 has gotten from dialogue_corpus.db.
# Dialogue:cleaning92 has gotten from dialogue_corpus.db.
# Dialogue:cleaning93 has gotten from dialogue_corpus.db.
# Dialogue:cleaning94 has gotten from dialogue_corpus.db.
# Dialogue:cleaning95 has gotten from dialogue_corpus.db.
# Dialogue:cleaning96 has gotten from dialogue_corpus.db.
# Dialogue:cleaning97 has gotten from dialogue_corpus.db.
# Dialogue:cleaning98 has gotten from dialogue_corpus.db.
# Dialogue:cleaning99 has gotten from dialogue_corpus.db.
# Dialogue:cleaning100 has gotten from dialogue_corpus.db.
# Dialogue:cleaning101 has gotten from dialogue_corpus.db.
# Dialogue:cleaning102 has gotten from dialogue_corpus.db.
# Dialogue:cleaning103 has gotten from dialogue_corpus.db.
# Dialogue:cleaning104 has gotten from dialogue_corpus.db.
# Dialogue:cleaning105 has gotten from dialogue_corpus.db.
# Dialogue:cleaning106 has gotten from dialogue_corpus.db.
# Dialogue:cleaning107 has gotten from dialogue_corpus.db.
# Dialogue:cleaning108 has gotten from dialogue_corpus.db.
# Dialogue:cleaning109 has gotten from dialogue_corpus.db.
# Dialogue:cleaning110 has gotten from dialogue_corpus.db.
# Dialogue:cleaning111 has gotten from dialogue_corpus.db.
# Dialogue:cleaning112 has gotten from dialogue_corpus.db.
# Dialogue:cleaning113 has gotten from dialogue_corpus.db.
# Dialogue:cleaning114 has gotten from dialogue_corpus.db.
# Dialogue:cleaning115 has gotten from dialogue_corpus.db.
# Dialogue:cleaning116 has gotten from dialogue_corpus.db.
# Dialogue:cleaning117 has gotten from dialogue_corpus.db.
# Dialogue:cleaning118 has gotten from dialogue_corpus.db.
# Dialogue:cleaning119 has gotten from dialogue_corpus.db.
# Dialogue:cleaning120 has gotten from dialogue_corpus.db.
# Dialogue:cleaning121 has gotten from dialogue_corpus.db.
# Dialogue:cleaning122 has gotten from dialogue_corpus.db.
# Dialogue:cleaning123 has gotten from dialogue_corpus.db.
# Dialogue:cleaning124 has gotten from dialogue_corpus.db.
# Dialogue:cleaning125 has gotten from dialogue_corpus.db.
# Dialogue:cleaning126 has gotten from dialogue_corpus.db.
# Dialogue:cleaning127 has gotten from dialogue_corpus.db.
# Dialogue:cleaning128 has gotten from dialogue_corpus.db.
# Dialogue:cleaning129 has gotten from dialogue_corpus.db.
# Dialogue:cleaning130 has gotten from dialogue_corpus.db.
# Dialogue:cleaning131 has gotten from dialogue_corpus.db.
# Dialogue:cleaning132 has gotten from dialogue_corpus.db.
# Dialogue:cleaning133 has gotten from dialogue_corpus.db.
# Dialogue:cleaning134 has gotten from dialogue_corpus.db.
# Dialogue:cleaning135 has gotten from dialogue_corpus.db.
# Dialogue:cleaning136 has gotten from dialogue_corpus.db.
# Dialogue:cleaning137 has gotten from dialogue_corpus.db.
# Dialogue:cleaning138 has gotten from dialogue_corpus.db.
# Dialogue:cleaning139 has gotten from dialogue_corpus.db.
# Dialogue:cleaning140 has gotten from dialogue_corpus.db.
# Dialogue:cleaning141 has gotten from dialogue_corpus.db.
# Dialogue:cleaning142 has gotten from dialogue_corpus.db.
# Dialogue:cleaning143 has gotten from dialogue_corpus.db.
# Dialogue:cleaning144 has gotten from dialogue_corpus.db.
# Dialogue:cleaning145 has gotten from dialogue_corpus.db.
# Dialogue:cleaning146 has gotten from dialogue_corpus.db.
# Dialogue:cleaning147 has gotten from dialogue_corpus.db.
# Dialogue:cleaning148 has gotten from dialogue_corpus.db.
# Dialogue:cleaning149 has gotten from dialogue_corpus.db.
# Dialogue:cleaning150 has gotten from dialogue_corpus.db.
# Dialogue:cleaning151 has gotten from dialogue_corpus.db.
# Dialogue:cleaning152 has gotten from dialogue_corpus.db.
# Dialogue:cleaning153 has gotten from dialogue_corpus.db.
# Dialogue:cleaning154 has gotten from dialogue_corpus.db.
# Dialogue:cleaning155 has gotten from dialogue_corpus.db.
# Dialogue:cleaning156 has gotten from dialogue_corpus.db.
# Dialogue:cleaning157 has gotten from dialogue_corpus.db.
# Dialogue:cleaning158 has gotten from dialogue_corpus.db.
# Dialogue:cleaning159 has gotten from dialogue_corpus.db.
# Dialogue:cleaning160 has gotten from dialogue_corpus.db.
# Dialogue:cleaning161 has gotten from dialogue_corpus.db.
# Dialogue:cleaning162 has gotten from dialogue_corpus.db.
# Dialogue:cleaning163 has gotten from dialogue_corpus.db.
# Dialogue:cleaning164 has gotten from dialogue_corpus.db.
# Dialogue:cleaning165 has gotten from dialogue_corpus.db.
# Dialogue:cleaning166 has gotten from dialogue_corpus.db.
# Dialogue:cleaning167 has gotten from dialogue_corpus.db.
# Dialogue:cleaning168 has gotten from dialogue_corpus.db.
# Dialogue:cleaning169 has gotten from dialogue_corpus.db.
# Dialogue:cleaning170 has gotten from dialogue_corpus.db.
# Dialogue:cleaning171 has gotten from dialogue_corpus.db.
# Dialogue:cleaning172 has gotten from dialogue_corpus.db.
# Dialogue:cleaning173 has gotten from dialogue_corpus.db.
# Dialogue:cleaning174 has gotten from dialogue_corpus.db.
# Dialogue:cleaning175 has gotten from dialogue_corpus.db.
# Dialogue:cleaning176 has gotten from dialogue_corpus.db.
# Dialogue:cleaning177 has gotten from dialogue_corpus.db.
# Dialogue:cleaning178 has gotten from dialogue_corpus.db.
# Dialogue:cleaning179 has gotten from dialogue_corpus.db.
# Dialogue:cleaning180 has gotten from dialogue_corpus.db.
# Dialogue:cleaning181 has gotten from dialogue_corpus.db.
# Dialogue:cleaning182 has gotten from dialogue_corpus.db.
# Dialogue:cleaning183 has gotten from dialogue_corpus.db.
# Dialogue:cleaning184 has gotten from dialogue_corpus.db.
# Dialogue:cleaning185 has gotten from dialogue_corpus.db.
# Dialogue:cleaning186 has gotten from dialogue_corpus.db.
# Dialogue:cleaning187 has gotten from dialogue_corpus.db.
# Dialogue:cleaning188 has gotten from dialogue_corpus.db.
# Dialogue:cleaning189 has gotten from dialogue_corpus.db.
# Dialogue:cleaning190 has gotten from dialogue_corpus.db.
# Dialogue:cleaning191 has gotten from dialogue_corpus.db.
# Dialogue:cleaning192 has gotten from dialogue_corpus.db.
# Dialogue:cleaning193 has gotten from dialogue_corpus.db.
# Dialogue:cleaning194 has gotten from dialogue_corpus.db.
# Dialogue:cleaning195 has gotten from dialogue_corpus.db.
# Dialogue:cleaning196 has gotten from dialogue_corpus.db.
# Dialogue:cleaning197 has gotten from dialogue_corpus.db.
# Dialogue:cleaning198 has gotten from dialogue_corpus.db.
# Dialogue:cleaning199 has gotten from dialogue_corpus.db.
# Dialogue:exercise0 has gotten from dialogue_corpus.db.
# Dialogue:exercise1 has gotten from dialogue_corpus.db.
# Dialogue:exercise2 has gotten from dialogue_corpus.db.
# Dialogue:exercise3 has gotten from dialogue_corpus.db.
# Dialogue:exercise4 has gotten from dialogue_corpus.db.
# Dialogue:exercise5 has gotten from dialogue_corpus.db.
# Dialogue:exercise6 has gotten from dialogue_corpus.db.
# Dialogue:exercise7 has gotten from dialogue_corpus.db.
# Dialogue:exercise8 has gotten from dialogue_corpus.db.
# Dialogue:exercise9 has gotten from dialogue_corpus.db.
# Dialogue:exercise10 has gotten from dialogue_corpus.db.
# Dialogue:exercise11 has gotten from dialogue_corpus.db.
# Dialogue:exercise12 has gotten from dialogue_corpus.db.
# Dialogue:exercise13 has gotten from dialogue_corpus.db.
# Dialogue:exercise14 has gotten from dialogue_corpus.db.
# Dialogue:exercise15 has gotten from dialogue_corpus.db.
# Dialogue:exercise16 has gotten from dialogue_corpus.db.
# Dialogue:exercise17 has gotten from dialogue_corpus.db.
# Dialogue:exercise18 has gotten from dialogue_corpus.db.
# Dialogue:exercise19 has gotten from dialogue_corpus.db.
# Dialogue:exercise20 has gotten from dialogue_corpus.db.
# Dialogue:exercise21 has gotten from dialogue_corpus.db.
# Dialogue:exercise22 has gotten from dialogue_corpus.db.
# Dialogue:exercise23 has gotten from dialogue_corpus.db.
# Dialogue:exercise24 has gotten from dialogue_corpus.db.
# Dialogue:exercise25 has gotten from dialogue_corpus.db.
# Dialogue:exercise26 has gotten from dialogue_corpus.db.
# Dialogue:exercise27 has gotten from dialogue_corpus.db.
# Dialogue:exercise28 has gotten from dialogue_corpus.db.
# Dialogue:exercise29 has gotten from dialogue_corpus.db.
# Dialogue:exercise30 has gotten from dialogue_corpus.db.
# Dialogue:exercise31 has gotten from dialogue_corpus.db.
# Dialogue:exercise32 has gotten from dialogue_corpus.db.
# Dialogue:exercise33 has gotten from dialogue_corpus.db.
# Dialogue:exercise34 has gotten from dialogue_corpus.db.
# Dialogue:exercise35 has gotten from dialogue_corpus.db.
# Dialogue:exercise36 has gotten from dialogue_corpus.db.
# Dialogue:exercise37 has gotten from dialogue_corpus.db.
# Dialogue:exercise38 has gotten from dialogue_corpus.db.
# Dialogue:exercise39 has gotten from dialogue_corpus.db.
# Dialogue:exercise40 has gotten from dialogue_corpus.db.
# Dialogue:exercise41 has gotten from dialogue_corpus.db.
# Dialogue:exercise42 has gotten from dialogue_corpus.db.
# Dialogue:exercise43 has gotten from dialogue_corpus.db.
# Dialogue:exercise44 has gotten from dialogue_corpus.db.
# Dialogue:exercise45 has gotten from dialogue_corpus.db.
# Dialogue:exercise46 has gotten from dialogue_corpus.db.
# Dialogue:exercise47 has gotten from dialogue_corpus.db.
# Dialogue:exercise48 has gotten from dialogue_corpus.db.
# Dialogue:exercise49 has gotten from dialogue_corpus.db.
# Dialogue:exercise50 has gotten from dialogue_corpus.db.
# Dialogue:exercise51 has gotten from dialogue_corpus.db.
# Dialogue:exercise52 has gotten from dialogue_corpus.db.
# Dialogue:exercise53 has gotten from dialogue_corpus.db.
# Dialogue:exercise54 has gotten from dialogue_corpus.db.
# Dialogue:exercise55 has gotten from dialogue_corpus.db.
# Dialogue:exercise56 has gotten from dialogue_corpus.db.
# Dialogue:exercise57 has gotten from dialogue_corpus.db.
# Dialogue:exercise58 has gotten from dialogue_corpus.db.
# Dialogue:exercise59 has gotten from dialogue_corpus.db.
# Dialogue:exercise60 has gotten from dialogue_corpus.db.
# Dialogue:exercise61 has gotten from dialogue_corpus.db.
# Dialogue:exercise62 has gotten from dialogue_corpus.db.
# Dialogue:exercise63 has gotten from dialogue_corpus.db.
# Dialogue:exercise64 has gotten from dialogue_corpus.db.
# Dialogue:exercise65 has gotten from dialogue_corpus.db.
# Dialogue:exercise66 has gotten from dialogue_corpus.db.
# Dialogue:exercise67 has gotten from dialogue_corpus.db.
# Dialogue:exercise68 has gotten from dialogue_corpus.db.
# Dialogue:exercise69 has gotten from dialogue_corpus.db.
# Dialogue:exercise70 has gotten from dialogue_corpus.db.
# Dialogue:exercise71 has gotten from dialogue_corpus.db.
# Dialogue:exercise72 has gotten from dialogue_corpus.db.
# Dialogue:exercise73 has gotten from dialogue_corpus.db.
# Dialogue:exercise74 has gotten from dialogue_corpus.db.
# Dialogue:exercise75 has gotten from dialogue_corpus.db.
# Dialogue:exercise76 has gotten from dialogue_corpus.db.
# Dialogue:exercise77 has gotten from dialogue_corpus.db.
# Dialogue:exercise78 has gotten from dialogue_corpus.db.
# Dialogue:exercise79 has gotten from dialogue_corpus.db.
# Dialogue:exercise80 has gotten from dialogue_corpus.db.
# Dialogue:exercise81 has gotten from dialogue_corpus.db.
# Dialogue:exercise82 has gotten from dialogue_corpus.db.
# Dialogue:exercise83 has gotten from dialogue_corpus.db.
# Dialogue:exercise84 has gotten from dialogue_corpus.db.
# Dialogue:exercise85 has gotten from dialogue_corpus.db.
# Dialogue:exercise86 has gotten from dialogue_corpus.db.
# Dialogue:exercise87 has gotten from dialogue_corpus.db.
# Dialogue:exercise88 has gotten from dialogue_corpus.db.
# Dialogue:exercise89 has gotten from dialogue_corpus.db.
# Dialogue:exercise90 has gotten from dialogue_corpus.db.
# Dialogue:exercise91 has gotten from dialogue_corpus.db.
# Dialogue:exercise92 has gotten from dialogue_corpus.db.
# Dialogue:exercise93 has gotten from dialogue_corpus.db.
# Dialogue:exercise94 has gotten from dialogue_corpus.db.
# Dialogue:exercise95 has gotten from dialogue_corpus.db.
# Dialogue:exercise96 has gotten from dialogue_corpus.db.
# Dialogue:exercise97 has gotten from dialogue_corpus.db.
# Dialogue:exercise98 has gotten from dialogue_corpus.db.
# Dialogue:exercise99 has gotten from dialogue_corpus.db.
# Dialogue:exercise100 has gotten from dialogue_corpus.db.
# Dialogue:exercise101 has gotten from dialogue_corpus.db.
# Dialogue:exercise102 has gotten from dialogue_corpus.db.
# Dialogue:exercise103 has gotten from dialogue_corpus.db.
# Dialogue:exercise104 has gotten from dialogue_corpus.db.
# Dialogue:exercise105 has gotten from dialogue_corpus.db.
# Dialogue:exercise106 has gotten from dialogue_corpus.db.
# Dialogue:exercise107 has gotten from dialogue_corpus.db.
# Dialogue:exercise108 has gotten from dialogue_corpus.db.
# Dialogue:exercise109 has gotten from dialogue_corpus.db.
# Dialogue:exercise110 has gotten from dialogue_corpus.db.
# Dialogue:exercise111 has gotten from dialogue_corpus.db.
# Dialogue:exercise112 has gotten from dialogue_corpus.db.
# Dialogue:exercise113 has gotten from dialogue_corpus.db.
# Dialogue:exercise114 has gotten from dialogue_corpus.db.
# Dialogue:exercise115 has gotten from dialogue_corpus.db.
# Dialogue:exercise116 has gotten from dialogue_corpus.db.
# Dialogue:exercise117 has gotten from dialogue_corpus.db.
# Dialogue:exercise118 has gotten from dialogue_corpus.db.
# Dialogue:exercise119 has gotten from dialogue_corpus.db.
# Dialogue:exercise120 has gotten from dialogue_corpus.db.
# Dialogue:exercise121 has gotten from dialogue_corpus.db.
# Dialogue:exercise122 has gotten from dialogue_corpus.db.
# Dialogue:exercise123 has gotten from dialogue_corpus.db.
# Dialogue:exercise124 has gotten from dialogue_corpus.db.
# Dialogue:exercise125 has gotten from dialogue_corpus.db.
# Dialogue:exercise126 has gotten from dialogue_corpus.db.
# Dialogue:exercise127 has gotten from dialogue_corpus.db.
# Dialogue:exercise128 has gotten from dialogue_corpus.db.
# Dialogue:exercise129 has gotten from dialogue_corpus.db.
# Dialogue:exercise130 has gotten from dialogue_corpus.db.
# Dialogue:exercise131 has gotten from dialogue_corpus.db.
# Dialogue:exercise132 has gotten from dialogue_corpus.db.
# Dialogue:exercise133 has gotten from dialogue_corpus.db.
# Dialogue:exercise134 has gotten from dialogue_corpus.db.
# Dialogue:exercise135 has gotten from dialogue_corpus.db.
# Dialogue:exercise136 has gotten from dialogue_corpus.db.
# Dialogue:exercise137 has gotten from dialogue_corpus.db.
# Dialogue:exercise138 has gotten from dialogue_corpus.db.
# Dialogue:exercise139 has gotten from dialogue_corpus.db.
# Dialogue:exercise140 has gotten from dialogue_corpus.db.
# Dialogue:exercise141 has gotten from dialogue_corpus.db.
# Dialogue:exercise142 has gotten from dialogue_corpus.db.
# Dialogue:exercise143 has gotten from dialogue_corpus.db.
# Dialogue:exercise144 has gotten from dialogue_corpus.db.
# Dialogue:exercise145 has gotten from dialogue_corpus.db.
# Dialogue:exercise146 has gotten from dialogue_corpus.db.
# Dialogue:exercise147 has gotten from dialogue_corpus.db.
# Dialogue:exercise148 has gotten from dialogue_corpus.db.
# Dialogue:exercise149 has gotten from dialogue_corpus.db.
# Dialogue:exercise150 has gotten from dialogue_corpus.db.
# Dialogue:exercise151 has gotten from dialogue_corpus.db.
# Dialogue:exercise152 has gotten from dialogue_corpus.db.
# Dialogue:exercise153 has gotten from dialogue_corpus.db.
# Dialogue:exercise154 has gotten from dialogue_corpus.db.
# Dialogue:exercise155 has gotten from dialogue_corpus.db.
# Dialogue:exercise156 has gotten from dialogue_corpus.db.
# Dialogue:exercise157 has gotten from dialogue_corpus.db.
# Dialogue:exercise158 has gotten from dialogue_corpus.db.
# Dialogue:exercise159 has gotten from dialogue_corpus.db.
# Dialogue:exercise160 has gotten from dialogue_corpus.db.
# Dialogue:exercise161 has gotten from dialogue_corpus.db.
# Dialogue:exercise162 has gotten from dialogue_corpus.db.
# Dialogue:exercise163 has gotten from dialogue_corpus.db.
# Dialogue:exercise164 has gotten from dialogue_corpus.db.
# Dialogue:exercise165 has gotten from dialogue_corpus.db.
# Dialogue:exercise166 has gotten from dialogue_corpus.db.
# Dialogue:exercise167 has gotten from dialogue_corpus.db.
# Dialogue:exercise168 has gotten from dialogue_corpus.db.
# Dialogue:exercise169 has gotten from dialogue_corpus.db.
# Dialogue:exercise170 has gotten from dialogue_corpus.db.
# Dialogue:exercise171 has gotten from dialogue_corpus.db.
# Dialogue:exercise172 has gotten from dialogue_corpus.db.
# Dialogue:exercise173 has gotten from dialogue_corpus.db.
# Dialogue:exercise174 has gotten from dialogue_corpus.db.
# Dialogue:exercise175 has gotten from dialogue_corpus.db.
# Dialogue:exercise176 has gotten from dialogue_corpus.db.
# Dialogue:exercise177 has gotten from dialogue_corpus.db.
# Dialogue:exercise178 has gotten from dialogue_corpus.db.
# Dialogue:exercise179 has gotten from dialogue_corpus.db.
# Dialogue:exercise180 has gotten from dialogue_corpus.db.
# Dialogue:exercise181 has gotten from dialogue_corpus.db.
# Dialogue:exercise182 has gotten from dialogue_corpus.db.
# Dialogue:exercise183 has gotten from dialogue_corpus.db.
# Dialogue:exercise184 has gotten from dialogue_corpus.db.
# Dialogue:exercise185 has gotten from dialogue_corpus.db.
# Dialogue:exercise186 has gotten from dialogue_corpus.db.
# Dialogue:exercise187 has gotten from dialogue_corpus.db.
# Dialogue:exercise188 has gotten from dialogue_corpus.db.
# Dialogue:exercise189 has gotten from dialogue_corpus.db.
# Dialogue:exercise190 has gotten from dialogue_corpus.db.
# Dialogue:exercise191 has gotten from dialogue_corpus.db.
# Dialogue:exercise192 has gotten from dialogue_corpus.db.
# Dialogue:exercise193 has gotten from dialogue_corpus.db.
# Dialogue:exercise194 has gotten from dialogue_corpus.db.
# Dialogue:exercise195 has gotten from dialogue_corpus.db.
# Dialogue:exercise196 has gotten from dialogue_corpus.db.
# Dialogue:exercise197 has gotten from dialogue_corpus.db.
# Dialogue:exercise198 has gotten from dialogue_corpus.db.
# Dialogue:exercise199 has gotten from dialogue_corpus.db.
# Dialogue:game0 has gotten from dialogue_corpus.db.
# Dialogue:game1 has gotten from dialogue_corpus.db.
# Dialogue:game2 has gotten from dialogue_corpus.db.
# Dialogue:game3 has gotten from dialogue_corpus.db.
# Dialogue:game4 has gotten from dialogue_corpus.db.
# Dialogue:game5 has gotten from dialogue_corpus.db.
# Dialogue:game6 has gotten from dialogue_corpus.db.
# Dialogue:game7 has gotten from dialogue_corpus.db.
# Dialogue:game8 has gotten from dialogue_corpus.db.
# Dialogue:game9 has gotten from dialogue_corpus.db.
# Dialogue:game10 has gotten from dialogue_corpus.db.
# Dialogue:game11 has gotten from dialogue_corpus.db.
# Dialogue:game12 has gotten from dialogue_corpus.db.
# Dialogue:game13 has gotten from dialogue_corpus.db.
# Dialogue:game14 has gotten from dialogue_corpus.db.
# Dialogue:game15 has gotten from dialogue_corpus.db.
# Dialogue:game16 has gotten from dialogue_corpus.db.
# Dialogue:game17 has gotten from dialogue_corpus.db.
# Dialogue:game18 has gotten from dialogue_corpus.db.
# Dialogue:game19 has gotten from dialogue_corpus.db.
# Dialogue:game20 has gotten from dialogue_corpus.db.
# Dialogue:game21 has gotten from dialogue_corpus.db.
# Dialogue:game22 has gotten from dialogue_corpus.db.
# Dialogue:game23 has gotten from dialogue_corpus.db.
# Dialogue:game24 has gotten from dialogue_corpus.db.
# Dialogue:game25 has gotten from dialogue_corpus.db.
# Dialogue:game26 has gotten from dialogue_corpus.db.
# Dialogue:game27 has gotten from dialogue_corpus.db.
# Dialogue:game28 has gotten from dialogue_corpus.db.
# Dialogue:game29 has gotten from dialogue_corpus.db.
# Dialogue:game30 has gotten from dialogue_corpus.db.
# Dialogue:game31 has gotten from dialogue_corpus.db.
# Dialogue:game32 has gotten from dialogue_corpus.db.
# Dialogue:game33 has gotten from dialogue_corpus.db.
# Dialogue:game34 has gotten from dialogue_corpus.db.
# Dialogue:game35 has gotten from dialogue_corpus.db.
# Dialogue:game36 has gotten from dialogue_corpus.db.
# Dialogue:game37 has gotten from dialogue_corpus.db.
# Dialogue:game38 has gotten from dialogue_corpus.db.
# Dialogue:game39 has gotten from dialogue_corpus.db.
# Dialogue:game40 has gotten from dialogue_corpus.db.
# Dialogue:game41 has gotten from dialogue_corpus.db.
# Dialogue:game42 has gotten from dialogue_corpus.db.
# Dialogue:game43 has gotten from dialogue_corpus.db.
# Dialogue:game44 has gotten from dialogue_corpus.db.
# Dialogue:game45 has gotten from dialogue_corpus.db.
# Dialogue:game46 has gotten from dialogue_corpus.db.
# Dialogue:game47 has gotten from dialogue_corpus.db.
# Dialogue:game48 has gotten from dialogue_corpus.db.
# Dialogue:game49 has gotten from dialogue_corpus.db.
# Dialogue:game50 has gotten from dialogue_corpus.db.
# Dialogue:game51 has gotten from dialogue_corpus.db.
# Dialogue:game52 has gotten from dialogue_corpus.db.
# Dialogue:game53 has gotten from dialogue_corpus.db.
# Dialogue:game54 has gotten from dialogue_corpus.db.
# Dialogue:game55 has gotten from dialogue_corpus.db.
# Dialogue:game56 has gotten from dialogue_corpus.db.
# Dialogue:game57 has gotten from dialogue_corpus.db.
# Dialogue:game58 has gotten from dialogue_corpus.db.
# Dialogue:game59 has gotten from dialogue_corpus.db.
# Dialogue:game60 has gotten from dialogue_corpus.db.
# Dialogue:game61 has gotten from dialogue_corpus.db.
# Dialogue:game62 has gotten from dialogue_corpus.db.
# Dialogue:game63 has gotten from dialogue_corpus.db.
# Dialogue:game64 has gotten from dialogue_corpus.db.
# Dialogue:game65 has gotten from dialogue_corpus.db.
# Dialogue:game66 has gotten from dialogue_corpus.db.
# Dialogue:game67 has gotten from dialogue_corpus.db.
# Dialogue:game68 has gotten from dialogue_corpus.db.
# Dialogue:game69 has gotten from dialogue_corpus.db.
# Dialogue:game70 has gotten from dialogue_corpus.db.
# Dialogue:game71 has gotten from dialogue_corpus.db.
# Dialogue:game72 has gotten from dialogue_corpus.db.
# Dialogue:game73 has gotten from dialogue_corpus.db.
# Dialogue:game74 has gotten from dialogue_corpus.db.
# Dialogue:game75 has gotten from dialogue_corpus.db.
# Dialogue:game76 has gotten from dialogue_corpus.db.
# Dialogue:game77 has gotten from dialogue_corpus.db.
# Dialogue:game78 has gotten from dialogue_corpus.db.
# Dialogue:game79 has gotten from dialogue_corpus.db.
# Dialogue:game80 has gotten from dialogue_corpus.db.
# Dialogue:game81 has gotten from dialogue_corpus.db.
# Dialogue:game82 has gotten from dialogue_corpus.db.
# Dialogue:game83 has gotten from dialogue_corpus.db.
# Dialogue:game84 has gotten from dialogue_corpus.db.
# Dialogue:game85 has gotten from dialogue_corpus.db.
# Dialogue:game86 has gotten from dialogue_corpus.db.
# Dialogue:game87 has gotten from dialogue_corpus.db.
# Dialogue:game88 has gotten from dialogue_corpus.db.
# Dialogue:game89 has gotten from dialogue_corpus.db.
# Dialogue:game90 has gotten from dialogue_corpus.db.
# Dialogue:game91 has gotten from dialogue_corpus.db.
# Dialogue:game92 has gotten from dialogue_corpus.db.
# Dialogue:game93 has gotten from dialogue_corpus.db.
# Dialogue:game94 has gotten from dialogue_corpus.db.
# Dialogue:game95 has gotten from dialogue_corpus.db.
# Dialogue:game96 has gotten from dialogue_corpus.db.
# Dialogue:game97 has gotten from dialogue_corpus.db.
# Dialogue:game98 has gotten from dialogue_corpus.db.
# Dialogue:game99 has gotten from dialogue_corpus.db.
# Dialogue:game100 has gotten from dialogue_corpus.db.
# Dialogue:game101 has gotten from dialogue_corpus.db.
# Dialogue:game102 has gotten from dialogue_corpus.db.
# Dialogue:game103 has gotten from dialogue_corpus.db.
# Dialogue:game104 has gotten from dialogue_corpus.db.
# Dialogue:game105 has gotten from dialogue_corpus.db.
# Dialogue:game106 has gotten from dialogue_corpus.db.
# Dialogue:game107 has gotten from dialogue_corpus.db.
# Dialogue:game108 has gotten from dialogue_corpus.db.
# Dialogue:game109 has gotten from dialogue_corpus.db.
# Dialogue:game110 has gotten from dialogue_corpus.db.
# Dialogue:game111 has gotten from dialogue_corpus.db.
# Dialogue:game112 has gotten from dialogue_corpus.db.
# Dialogue:game113 has gotten from dialogue_corpus.db.
# Dialogue:game114 has gotten from dialogue_corpus.db.
# Dialogue:game115 has gotten from dialogue_corpus.db.
# Dialogue:game116 has gotten from dialogue_corpus.db.
# Dialogue:game117 has gotten from dialogue_corpus.db.
# Dialogue:game118 has gotten from dialogue_corpus.db.
# Dialogue:game119 has gotten from dialogue_corpus.db.
# Dialogue:game120 has gotten from dialogue_corpus.db.
# Dialogue:game121 has gotten from dialogue_corpus.db.
# Dialogue:game122 has gotten from dialogue_corpus.db.
# Dialogue:game123 has gotten from dialogue_corpus.db.
# Dialogue:game124 has gotten from dialogue_corpus.db.
# Dialogue:game125 has gotten from dialogue_corpus.db.
# Dialogue:game126 has gotten from dialogue_corpus.db.
# Dialogue:game127 has gotten from dialogue_corpus.db.
# Dialogue:game128 has gotten from dialogue_corpus.db.
# Dialogue:game129 has gotten from dialogue_corpus.db.
# Dialogue:game130 has gotten from dialogue_corpus.db.
# Dialogue:game131 has gotten from dialogue_corpus.db.
# Dialogue:game132 has gotten from dialogue_corpus.db.
# Dialogue:game133 has gotten from dialogue_corpus.db.
# Dialogue:game134 has gotten from dialogue_corpus.db.
# Dialogue:game135 has gotten from dialogue_corpus.db.
# Dialogue:game136 has gotten from dialogue_corpus.db.
# Dialogue:game137 has gotten from dialogue_corpus.db.
# Dialogue:game138 has gotten from dialogue_corpus.db.
# Dialogue:game139 has gotten from dialogue_corpus.db.
# Dialogue:game140 has gotten from dialogue_corpus.db.
# Dialogue:game141 has gotten from dialogue_corpus.db.
# Dialogue:game142 has gotten from dialogue_corpus.db.
# Dialogue:game143 has gotten from dialogue_corpus.db.
# Dialogue:game144 has gotten from dialogue_corpus.db.
# Dialogue:game145 has gotten from dialogue_corpus.db.
# Dialogue:game146 has gotten from dialogue_corpus.db.
# Dialogue:game147 has gotten from dialogue_corpus.db.
# Dialogue:game148 has gotten from dialogue_corpus.db.
# Dialogue:game149 has gotten from dialogue_corpus.db.
# Dialogue:game150 has gotten from dialogue_corpus.db.
# Dialogue:game151 has gotten from dialogue_corpus.db.
# Dialogue:game152 has gotten from dialogue_corpus.db.
# Dialogue:game153 has gotten from dialogue_corpus.db.
# Dialogue:game154 has gotten from dialogue_corpus.db.
# Dialogue:game155 has gotten from dialogue_corpus.db.
# Dialogue:game156 has gotten from dialogue_corpus.db.
# Dialogue:game157 has gotten from dialogue_corpus.db.
# Dialogue:game158 has gotten from dialogue_corpus.db.
# Dialogue:game159 has gotten from dialogue_corpus.db.
# Dialogue:game160 has gotten from dialogue_corpus.db.
# Dialogue:game161 has gotten from dialogue_corpus.db.
# Dialogue:game162 has gotten from dialogue_corpus.db.
# Dialogue:game163 has gotten from dialogue_corpus.db.
# Dialogue:game164 has gotten from dialogue_corpus.db.
# Dialogue:game165 has gotten from dialogue_corpus.db.
# Dialogue:game166 has gotten from dialogue_corpus.db.
# Dialogue:game167 has gotten from dialogue_corpus.db.
# Dialogue:game168 has gotten from dialogue_corpus.db.
# Dialogue:game169 has gotten from dialogue_corpus.db.
# Dialogue:game170 has gotten from dialogue_corpus.db.
# Dialogue:game171 has gotten from dialogue_corpus.db.
# Dialogue:game172 has gotten from dialogue_corpus.db.
# Dialogue:game173 has gotten from dialogue_corpus.db.
# Dialogue:game174 has gotten from dialogue_corpus.db.
# Dialogue:game175 has gotten from dialogue_corpus.db.
# Dialogue:game176 has gotten from dialogue_corpus.db.
# Dialogue:game177 has gotten from dialogue_corpus.db.
# Dialogue:game178 has gotten from dialogue_corpus.db.
# Dialogue:game179 has gotten from dialogue_corpus.db.
# Dialogue:game180 has gotten from dialogue_corpus.db.
# Dialogue:game181 has gotten from dialogue_corpus.db.
# Dialogue:game182 has gotten from dialogue_corpus.db.
# Dialogue:game183 has gotten from dialogue_corpus.db.
# Dialogue:game184 has gotten from dialogue_corpus.db.
# Dialogue:game185 has gotten from dialogue_corpus.db.
# Dialogue:game186 has gotten from dialogue_corpus.db.
# Dialogue:game187 has gotten from dialogue_corpus.db.
# Dialogue:game188 has gotten from dialogue_corpus.db.
# Dialogue:game189 has gotten from dialogue_corpus.db.
# Dialogue:game190 has gotten from dialogue_corpus.db.
# Dialogue:game191 has gotten from dialogue_corpus.db.
# Dialogue:game192 has gotten from dialogue_corpus.db.
# Dialogue:game193 has gotten from dialogue_corpus.db.
# Dialogue:game194 has gotten from dialogue_corpus.db.
# Dialogue:game195 has gotten from dialogue_corpus.db.
# Dialogue:game196 has gotten from dialogue_corpus.db.
# Dialogue:game197 has gotten from dialogue_corpus.db.
# Dialogue:game198 has gotten from dialogue_corpus.db.
# Dialogue:game199 has gotten from dialogue_corpus.db.
# Dialogue:lunch0 has gotten from dialogue_corpus.db.
# Dialogue:lunch1 has gotten from dialogue_corpus.db.
# Dialogue:lunch2 has gotten from dialogue_corpus.db.
# Dialogue:lunch3 has gotten from dialogue_corpus.db.
# Dialogue:lunch4 has gotten from dialogue_corpus.db.
# Dialogue:lunch5 has gotten from dialogue_corpus.db.
# Dialogue:lunch6 has gotten from dialogue_corpus.db.
# Dialogue:lunch7 has gotten from dialogue_corpus.db.
# Dialogue:lunch8 has gotten from dialogue_corpus.db.
# Dialogue:lunch9 has gotten from dialogue_corpus.db.
# Dialogue:lunch10 has gotten from dialogue_corpus.db.
# Dialogue:lunch11 has gotten from dialogue_corpus.db.
# Dialogue:lunch12 has gotten from dialogue_corpus.db.
# Dialogue:lunch13 has gotten from dialogue_corpus.db.
# Dialogue:lunch14 has gotten from dialogue_corpus.db.
# Dialogue:lunch15 has gotten from dialogue_corpus.db.
# Dialogue:lunch16 has gotten from dialogue_corpus.db.
# Dialogue:lunch17 has gotten from dialogue_corpus.db.
# Dialogue:lunch18 has gotten from dialogue_corpus.db.
# Dialogue:lunch19 has gotten from dialogue_corpus.db.
# Dialogue:lunch20 has gotten from dialogue_corpus.db.
# Dialogue:lunch21 has gotten from dialogue_corpus.db.
# Dialogue:lunch22 has gotten from dialogue_corpus.db.
# Dialogue:lunch23 has gotten from dialogue_corpus.db.
# Dialogue:lunch24 has gotten from dialogue_corpus.db.
# Dialogue:lunch25 has gotten from dialogue_corpus.db.
# Dialogue:lunch26 has gotten from dialogue_corpus.db.
# Dialogue:lunch27 has gotten from dialogue_corpus.db.
# Dialogue:lunch28 has gotten from dialogue_corpus.db.
# Dialogue:lunch29 has gotten from dialogue_corpus.db.
# Dialogue:lunch30 has gotten from dialogue_corpus.db.
# Dialogue:lunch31 has gotten from dialogue_corpus.db.
# Dialogue:lunch32 has gotten from dialogue_corpus.db.
# Dialogue:lunch33 has gotten from dialogue_corpus.db.
# Dialogue:lunch34 has gotten from dialogue_corpus.db.
# Dialogue:lunch35 has gotten from dialogue_corpus.db.
# Dialogue:lunch36 has gotten from dialogue_corpus.db.
# Dialogue:lunch37 has gotten from dialogue_corpus.db.
# Dialogue:lunch38 has gotten from dialogue_corpus.db.
# Dialogue:lunch39 has gotten from dialogue_corpus.db.
# Dialogue:lunch40 has gotten from dialogue_corpus.db.
# Dialogue:lunch41 has gotten from dialogue_corpus.db.
# Dialogue:lunch42 has gotten from dialogue_corpus.db.
# Dialogue:lunch43 has gotten from dialogue_corpus.db.
# Dialogue:lunch44 has gotten from dialogue_corpus.db.
# Dialogue:lunch45 has gotten from dialogue_corpus.db.
# Dialogue:lunch46 has gotten from dialogue_corpus.db.
# Dialogue:lunch47 has gotten from dialogue_corpus.db.
# Dialogue:lunch48 has gotten from dialogue_corpus.db.
# Dialogue:lunch49 has gotten from dialogue_corpus.db.
# Dialogue:lunch50 has gotten from dialogue_corpus.db.
# Dialogue:lunch51 has gotten from dialogue_corpus.db.
# Dialogue:lunch52 has gotten from dialogue_corpus.db.
# Dialogue:lunch53 has gotten from dialogue_corpus.db.
# Dialogue:lunch54 has gotten from dialogue_corpus.db.
# Dialogue:lunch55 has gotten from dialogue_corpus.db.
# Dialogue:lunch56 has gotten from dialogue_corpus.db.
# Dialogue:lunch57 has gotten from dialogue_corpus.db.
# Dialogue:lunch58 has gotten from dialogue_corpus.db.
# Dialogue:lunch59 has gotten from dialogue_corpus.db.
# Dialogue:lunch60 has gotten from dialogue_corpus.db.
# Dialogue:lunch61 has gotten from dialogue_corpus.db.
# Dialogue:lunch62 has gotten from dialogue_corpus.db.
# Dialogue:lunch63 has gotten from dialogue_corpus.db.
# Dialogue:lunch64 has gotten from dialogue_corpus.db.
# Dialogue:lunch65 has gotten from dialogue_corpus.db.
# Dialogue:lunch66 has gotten from dialogue_corpus.db.
# Dialogue:lunch67 has gotten from dialogue_corpus.db.
# Dialogue:lunch68 has gotten from dialogue_corpus.db.
# Dialogue:lunch69 has gotten from dialogue_corpus.db.
# Dialogue:lunch70 has gotten from dialogue_corpus.db.
# Dialogue:lunch71 has gotten from dialogue_corpus.db.
# Dialogue:lunch72 has gotten from dialogue_corpus.db.
# Dialogue:lunch73 has gotten from dialogue_corpus.db.
# Dialogue:lunch74 has gotten from dialogue_corpus.db.
# Dialogue:lunch75 has gotten from dialogue_corpus.db.
# Dialogue:lunch76 has gotten from dialogue_corpus.db.
# Dialogue:lunch77 has gotten from dialogue_corpus.db.
# Dialogue:lunch78 has gotten from dialogue_corpus.db.
# Dialogue:lunch79 has gotten from dialogue_corpus.db.
# Dialogue:lunch80 has gotten from dialogue_corpus.db.
# Dialogue:lunch81 has gotten from dialogue_corpus.db.
# Dialogue:lunch82 has gotten from dialogue_corpus.db.
# Dialogue:lunch83 has gotten from dialogue_corpus.db.
# Dialogue:lunch84 has gotten from dialogue_corpus.db.
# Dialogue:lunch85 has gotten from dialogue_corpus.db.
# Dialogue:lunch86 has gotten from dialogue_corpus.db.
# Dialogue:lunch87 has gotten from dialogue_corpus.db.
# Dialogue:lunch88 has gotten from dialogue_corpus.db.
# Dialogue:lunch89 has gotten from dialogue_corpus.db.
# Dialogue:lunch90 has gotten from dialogue_corpus.db.
# Dialogue:lunch91 has gotten from dialogue_corpus.db.
# Dialogue:lunch92 has gotten from dialogue_corpus.db.
# Dialogue:lunch93 has gotten from dialogue_corpus.db.
# Dialogue:lunch94 has gotten from dialogue_corpus.db.
# Dialogue:lunch95 has gotten from dialogue_corpus.db.
# Dialogue:lunch96 has gotten from dialogue_corpus.db.
# Dialogue:lunch97 has gotten from dialogue_corpus.db.
# Dialogue:lunch98 has gotten from dialogue_corpus.db.
# Dialogue:lunch99 has gotten from dialogue_corpus.db.
# Dialogue:lunch100 has gotten from dialogue_corpus.db.
# Dialogue:lunch101 has gotten from dialogue_corpus.db.
# Dialogue:lunch102 has gotten from dialogue_corpus.db.
# Dialogue:lunch103 has gotten from dialogue_corpus.db.
# Dialogue:lunch104 has gotten from dialogue_corpus.db.
# Dialogue:lunch105 has gotten from dialogue_corpus.db.
# Dialogue:lunch106 has gotten from dialogue_corpus.db.
# Dialogue:lunch107 has gotten from dialogue_corpus.db.
# Dialogue:lunch108 has gotten from dialogue_corpus.db.
# Dialogue:lunch109 has gotten from dialogue_corpus.db.
# Dialogue:lunch110 has gotten from dialogue_corpus.db.
# Dialogue:lunch111 has gotten from dialogue_corpus.db.
# Dialogue:lunch112 has gotten from dialogue_corpus.db.
# Dialogue:lunch113 has gotten from dialogue_corpus.db.
# Dialogue:lunch114 has gotten from dialogue_corpus.db.
# Dialogue:lunch115 has gotten from dialogue_corpus.db.
# Dialogue:lunch116 has gotten from dialogue_corpus.db.
# Dialogue:lunch117 has gotten from dialogue_corpus.db.
# Dialogue:lunch118 has gotten from dialogue_corpus.db.
# Dialogue:lunch119 has gotten from dialogue_corpus.db.
# Dialogue:lunch120 has gotten from dialogue_corpus.db.
# Dialogue:lunch121 has gotten from dialogue_corpus.db.
# Dialogue:lunch122 has gotten from dialogue_corpus.db.
# Dialogue:lunch123 has gotten from dialogue_corpus.db.
# Dialogue:lunch124 has gotten from dialogue_corpus.db.
# Dialogue:lunch125 has gotten from dialogue_corpus.db.
# Dialogue:lunch126 has gotten from dialogue_corpus.db.
# Dialogue:lunch127 has gotten from dialogue_corpus.db.
# Dialogue:lunch128 has gotten from dialogue_corpus.db.
# Dialogue:lunch129 has gotten from dialogue_corpus.db.
# Dialogue:lunch130 has gotten from dialogue_corpus.db.
# Dialogue:lunch131 has gotten from dialogue_corpus.db.
# Dialogue:lunch132 has gotten from dialogue_corpus.db.
# Dialogue:lunch133 has gotten from dialogue_corpus.db.
# Dialogue:lunch134 has gotten from dialogue_corpus.db.
# Dialogue:lunch135 has gotten from dialogue_corpus.db.
# Dialogue:lunch136 has gotten from dialogue_corpus.db.
# Dialogue:lunch137 has gotten from dialogue_corpus.db.
# Dialogue:lunch138 has gotten from dialogue_corpus.db.
# Dialogue:lunch139 has gotten from dialogue_corpus.db.
# Dialogue:lunch140 has gotten from dialogue_corpus.db.
# Dialogue:lunch141 has gotten from dialogue_corpus.db.
# Dialogue:lunch142 has gotten from dialogue_corpus.db.
# Dialogue:lunch143 has gotten from dialogue_corpus.db.
# Dialogue:lunch144 has gotten from dialogue_corpus.db.
# Dialogue:lunch145 has gotten from dialogue_corpus.db.
# Dialogue:lunch146 has gotten from dialogue_corpus.db.
# Dialogue:lunch147 has gotten from dialogue_corpus.db.
# Dialogue:lunch148 has gotten from dialogue_corpus.db.
# Dialogue:lunch149 has gotten from dialogue_corpus.db.
# Dialogue:lunch150 has gotten from dialogue_corpus.db.
# Dialogue:lunch151 has gotten from dialogue_corpus.db.
# Dialogue:lunch152 has gotten from dialogue_corpus.db.
# Dialogue:lunch153 has gotten from dialogue_corpus.db.
# Dialogue:lunch154 has gotten from dialogue_corpus.db.
# Dialogue:lunch155 has gotten from dialogue_corpus.db.
# Dialogue:lunch156 has gotten from dialogue_corpus.db.
# Dialogue:lunch157 has gotten from dialogue_corpus.db.
# Dialogue:lunch158 has gotten from dialogue_corpus.db.
# Dialogue:lunch159 has gotten from dialogue_corpus.db.
# Dialogue:lunch160 has gotten from dialogue_corpus.db.
# Dialogue:lunch161 has gotten from dialogue_corpus.db.
# Dialogue:lunch162 has gotten from dialogue_corpus.db.
# Dialogue:lunch163 has gotten from dialogue_corpus.db.
# Dialogue:lunch164 has gotten from dialogue_corpus.db.
# Dialogue:lunch165 has gotten from dialogue_corpus.db.
# Dialogue:lunch166 has gotten from dialogue_corpus.db.
# Dialogue:lunch167 has gotten from dialogue_corpus.db.
# Dialogue:lunch168 has gotten from dialogue_corpus.db.
# Dialogue:lunch169 has gotten from dialogue_corpus.db.
# Dialogue:lunch170 has gotten from dialogue_corpus.db.
# Dialogue:lunch171 has gotten from dialogue_corpus.db.
# Dialogue:lunch172 has gotten from dialogue_corpus.db.
# Dialogue:lunch173 has gotten from dialogue_corpus.db.
# Dialogue:lunch174 has gotten from dialogue_corpus.db.
# Dialogue:lunch175 has gotten from dialogue_corpus.db.
# Dialogue:lunch176 has gotten from dialogue_corpus.db.
# Dialogue:lunch177 has gotten from dialogue_corpus.db.
# Dialogue:lunch178 has gotten from dialogue_corpus.db.
# Dialogue:lunch179 has gotten from dialogue_corpus.db.
# Dialogue:lunch180 has gotten from dialogue_corpus.db.
# Dialogue:lunch181 has gotten from dialogue_corpus.db.
# Dialogue:lunch182 has gotten from dialogue_corpus.db.
# Dialogue:lunch183 has gotten from dialogue_corpus.db.
# Dialogue:lunch184 has gotten from dialogue_corpus.db.
# Dialogue:lunch185 has gotten from dialogue_corpus.db.
# Dialogue:lunch186 has gotten from dialogue_corpus.db.
# Dialogue:lunch187 has gotten from dialogue_corpus.db.
# Dialogue:lunch188 has gotten from dialogue_corpus.db.
# Dialogue:lunch189 has gotten from dialogue_corpus.db.
# Dialogue:lunch190 has gotten from dialogue_corpus.db.
# Dialogue:lunch191 has gotten from dialogue_corpus.db.
# Dialogue:lunch192 has gotten from dialogue_corpus.db.
# Dialogue:lunch193 has gotten from dialogue_corpus.db.
# Dialogue:lunch194 has gotten from dialogue_corpus.db.
# Dialogue:lunch195 has gotten from dialogue_corpus.db.
# Dialogue:lunch196 has gotten from dialogue_corpus.db.
# Dialogue:lunch197 has gotten from dialogue_corpus.db.
# Dialogue:lunch198 has gotten from dialogue_corpus.db.
# Dialogue:lunch199 has gotten from dialogue_corpus.db.
# Dialogue:sleep0 has gotten from dialogue_corpus.db.
# Dialogue:sleep1 has gotten from dialogue_corpus.db.
# Dialogue:sleep2 has gotten from dialogue_corpus.db.
# Dialogue:sleep3 has gotten from dialogue_corpus.db.
# Dialogue:sleep4 has gotten from dialogue_corpus.db.
# Dialogue:sleep5 has gotten from dialogue_corpus.db.
# Dialogue:sleep6 has gotten from dialogue_corpus.db.
# Dialogue:sleep7 has gotten from dialogue_corpus.db.
# Dialogue:sleep8 has gotten from dialogue_corpus.db.
# Dialogue:sleep9 has gotten from dialogue_corpus.db.
# Dialogue:sleep10 has gotten from dialogue_corpus.db.
# Dialogue:sleep11 has gotten from dialogue_corpus.db.
# Dialogue:sleep12 has gotten from dialogue_corpus.db.
# Dialogue:sleep13 has gotten from dialogue_corpus.db.
# Dialogue:sleep14 has gotten from dialogue_corpus.db.
# Dialogue:sleep15 has gotten from dialogue_corpus.db.
# Dialogue:sleep16 has gotten from dialogue_corpus.db.
# Dialogue:sleep17 has gotten from dialogue_corpus.db.
# Dialogue:sleep18 has gotten from dialogue_corpus.db.
# Dialogue:sleep19 has gotten from dialogue_corpus.db.
# Dialogue:sleep20 has gotten from dialogue_corpus.db.
# Dialogue:sleep21 has gotten from dialogue_corpus.db.
# Dialogue:sleep22 has gotten from dialogue_corpus.db.
# Dialogue:sleep23 has gotten from dialogue_corpus.db.
# Dialogue:sleep24 has gotten from dialogue_corpus.db.
# Dialogue:sleep25 has gotten from dialogue_corpus.db.
# Dialogue:sleep26 has gotten from dialogue_corpus.db.
# Dialogue:sleep27 has gotten from dialogue_corpus.db.
# Dialogue:sleep28 has gotten from dialogue_corpus.db.
# Dialogue:sleep29 has gotten from dialogue_corpus.db.
# Dialogue:sleep30 has gotten from dialogue_corpus.db.
# Dialogue:sleep31 has gotten from dialogue_corpus.db.
# Dialogue:sleep32 has gotten from dialogue_corpus.db.
# Dialogue:sleep33 has gotten from dialogue_corpus.db.
# Dialogue:sleep34 has gotten from dialogue_corpus.db.
# Dialogue:sleep35 has gotten from dialogue_corpus.db.
# Dialogue:sleep36 has gotten from dialogue_corpus.db.
# Dialogue:sleep37 has gotten from dialogue_corpus.db.
# Dialogue:sleep38 has gotten from dialogue_corpus.db.
# Dialogue:sleep39 has gotten from dialogue_corpus.db.
# Dialogue:sleep40 has gotten from dialogue_corpus.db.
# Dialogue:sleep41 has gotten from dialogue_corpus.db.
# Dialogue:sleep42 has gotten from dialogue_corpus.db.
# Dialogue:sleep43 has gotten from dialogue_corpus.db.
# Dialogue:sleep44 has gotten from dialogue_corpus.db.
# Dialogue:sleep45 has gotten from dialogue_corpus.db.
# Dialogue:sleep46 has gotten from dialogue_corpus.db.
# Dialogue:sleep47 has gotten from dialogue_corpus.db.
# Dialogue:sleep48 has gotten from dialogue_corpus.db.
# Dialogue:sleep49 has gotten from dialogue_corpus.db.
# Dialogue:sleep50 has gotten from dialogue_corpus.db.
# Dialogue:sleep51 has gotten from dialogue_corpus.db.
# Dialogue:sleep52 has gotten from dialogue_corpus.db.
# Dialogue:sleep53 has gotten from dialogue_corpus.db.
# Dialogue:sleep54 has gotten from dialogue_corpus.db.
# Dialogue:sleep55 has gotten from dialogue_corpus.db.
# Dialogue:sleep56 has gotten from dialogue_corpus.db.
# Dialogue:sleep57 has gotten from dialogue_corpus.db.
# Dialogue:sleep58 has gotten from dialogue_corpus.db.
# Dialogue:sleep59 has gotten from dialogue_corpus.db.
# Dialogue:sleep60 has gotten from dialogue_corpus.db.
# Dialogue:sleep61 has gotten from dialogue_corpus.db.
# Dialogue:sleep62 has gotten from dialogue_corpus.db.
# Dialogue:sleep63 has gotten from dialogue_corpus.db.
# Dialogue:sleep64 has gotten from dialogue_corpus.db.
# Dialogue:sleep65 has gotten from dialogue_corpus.db.
# Dialogue:sleep66 has gotten from dialogue_corpus.db.
# Dialogue:sleep67 has gotten from dialogue_corpus.db.
# Dialogue:sleep68 has gotten from dialogue_corpus.db.
# Dialogue:sleep69 has gotten from dialogue_corpus.db.
# Dialogue:sleep70 has gotten from dialogue_corpus.db.
# Dialogue:sleep71 has gotten from dialogue_corpus.db.
# Dialogue:sleep72 has gotten from dialogue_corpus.db.
# Dialogue:sleep73 has gotten from dialogue_corpus.db.
# Dialogue:sleep74 has gotten from dialogue_corpus.db.
# Dialogue:sleep75 has gotten from dialogue_corpus.db.
# Dialogue:sleep76 has gotten from dialogue_corpus.db.
# Dialogue:sleep77 has gotten from dialogue_corpus.db.
# Dialogue:sleep78 has gotten from dialogue_corpus.db.
# Dialogue:sleep79 has gotten from dialogue_corpus.db.
# ...
# 570 usertalks have been registered.
# 571 usertalks have been registered.
# 572 usertalks have been registered.
# 573 usertalks have been registered.
# 574 usertalks have been registered.
# 575 usertalks have been registered.
# 576 usertalks have been registered.
# 577 usertalks have been registered.
# 578 usertalks have been registered.
# 579 usertalks have been registered.
# 580 usertalks have been registered.
# 581 usertalks have been registered.
# 582 usertalks have been registered.
# 583 usertalks have been registered.
# 584 usertalks have been registered.
# 585 usertalks have been registered.
# 586 usertalks have been registered.
# 587 usertalks have been registered.
# 588 usertalks have been registered.
# 589 usertalks have been registered.
# 590 usertalks have been registered.
# 591 usertalks have been registered.
# 592 usertalks have been registered.
# 593 usertalks have been registered.
# 594 usertalks have been registered.
# 595 usertalks have been registered.
# 596 usertalks have been registered.
# 597 usertalks have been registered.
# 598 usertalks have been registered.
# 599 usertalks have been registered.
# 600 usertalks have been registered.
# 601 usertalks have been registered.
# 602 usertalks have been registered.
# 603 usertalks have been registered.
# 604 usertalks have been registered.
# 605 usertalks have been registered.
# 606 usertalks have been registered.
# 607 usertalks have been registered.
# 608 usertalks have been registered.
# 609 usertalks have been registered.
# 610 usertalks have been registered.
# 611 usertalks have been registered.
# 612 usertalks have been registered.
# 613 usertalks have been registered.
# 614 usertalks have been registered.
# 615 usertalks have been registered.
# 616 usertalks have been registered.
# 617 usertalks have been registered.
# 618 usertalks have been registered.
# 619 usertalks have been registered.
# 620 usertalks have been registered.
# 621 usertalks have been registered.
# 622 usertalks have been registered.
# 623 usertalks have been registered.
# 624 usertalks have been registered.
# 625 usertalks have been registered.
# 626 usertalks have been registered.
# 627 usertalks have been registered.
# 628 usertalks have been registered.
# 629 usertalks have been registered.
# 630 usertalks have been registered.
# 631 usertalks have been registered.
# 632 usertalks have been registered.
# 633 usertalks have been registered.
# 634 usertalks have been registered.
# 635 usertalks have been registered.
# 636 usertalks have been registered.
# 637 usertalks have been registered.
# 638 usertalks have been registered.
# 639 usertalks have been registered.
# 640 usertalks have been registered.
# 641 usertalks have been registered.
# 642 usertalks have been registered.
# 643 usertalks have been registered.
# 644 usertalks have been registered.
# 645 usertalks have been registered.
# 646 usertalks have been registered.
# 647 usertalks have been registered.
# 648 usertalks have been registered.
# 649 usertalks have been registered.
# 650 usertalks have been registered.
# 651 usertalks have been registered.
# 652 usertalks have been registered.
# 653 usertalks have been registered.
# 654 usertalks have been registered.
# 655 usertalks have been registered.
# 656 usertalks have been registered.
# 657 usertalks have been registered.
# 658 usertalks have been registered.
# 659 usertalks have been registered.
# 660 usertalks have been registered.
# 661 usertalks have been registered.
# 662 usertalks have been registered.
# 663 usertalks have been registered.
# 664 usertalks have been registered.
# 665 usertalks have been registered.
# 666 usertalks have been registered.
# 667 usertalks have been registered.
# 668 usertalks have been registered.
# 669 usertalks have been registered.
# 670 usertalks have been registered.
# 671 usertalks have been registered.
# 672 usertalks have been registered.
# 673 usertalks have been registered.
# 674 usertalks have been registered.
# 675 usertalks have been registered.
# 676 usertalks have been registered.
# 677 usertalks have been registered.
# 678 usertalks have been registered.
# 679 usertalks have been registered.
# 680 usertalks have been registered.
# 681 usertalks have been registered.
# 682 usertalks have been registered.
# 683 usertalks have been registered.
# 684 usertalks have been registered.
# 685 usertalks have been registered.
# 686 usertalks have been registered.
# 687 usertalks have been registered.
# 688 usertalks have been registered.
# 689 usertalks have been registered.
# 690 usertalks have been registered.
# 691 usertalks have been registered.
# 692 usertalks have been registered.
# 693 usertalks have been registered.
# 694 usertalks have been registered.
# 695 usertalks have been registered.
# 696 usertalks have been registered.
# 697 usertalks have been registered.
# 698 usertalks have been registered.
# 699 usertalks have been registered.
# 700 usertalks have been registered.
# 701 usertalks have been registered.
# 702 usertalks have been registered.
# 703 usertalks have been registered.
# 704 usertalks have been registered.
# 705 usertalks have been registered.
# 706 usertalks have been registered.
# 707 usertalks have been registered.
# 708 usertalks have been registered.
# 709 usertalks have been registered.
# 710 usertalks have been registered.
# 711 usertalks have been registered.
# 712 usertalks have been registered.
# 713 usertalks have been registered.
# 714 usertalks have been registered.
# 715 usertalks have been registered.
# 716 usertalks have been registered.
# 717 usertalks have been registered.
# 718 usertalks have been registered.
# 719 usertalks have been registered.
# 720 usertalks have been registered.
# 721 usertalks have been registered.
# 722 usertalks have been registered.
# 723 usertalks have been registered.
# 724 usertalks have been registered.
# 725 usertalks have been registered.
# 726 usertalks have been registered.
# 727 usertalks have been registered.
# 728 usertalks have been registered.
# 729 usertalks have been registered.
# 730 usertalks have been registered.
# 731 usertalks have been registered.
# 732 usertalks have been registered.
# 733 usertalks have been registered.
# 734 usertalks have been registered.
# 735 usertalks have been registered.
# 736 usertalks have been registered.
# 737 usertalks have been registered.
# 738 usertalks have been registered.
# 739 usertalks have been registered.
# 740 usertalks have been registered.
# 741 usertalks have been registered.
# 742 usertalks have been registered.
# 743 usertalks have been registered.
# 744 usertalks have been registered.
# 745 usertalks have been registered.
# 746 usertalks have been registered.
# 747 usertalks have been registered.
# 748 usertalks have been registered.
# 749 usertalks have been registered.
# 750 usertalks have been registered.
# 751 usertalks have been registered.
# 752 usertalks have been registered.
# 753 usertalks have been registered.
# 754 usertalks have been registered.
# 755 usertalks have been registered.
# 756 usertalks have been registered.
# 757 usertalks have been registered.
# 758 usertalks have been registered.
# 759 usertalks have been registered.
# 760 usertalks have been registered.
# 761 usertalks have been registered.
# 762 usertalks have been registered.
# 763 usertalks have been registered.
# 764 usertalks have been registered.
# 765 usertalks have been registered.
# 766 usertalks have been registered.
# 767 usertalks have been registered.
# 768 usertalks have been registered.
# 769 usertalks have been registered.
# 770 usertalks have been registered.
# 771 usertalks have been registered.
# 772 usertalks have been registered.
# 773 usertalks have been registered.
# 774 usertalks have been registered.
# 775 usertalks have been registered.
# 776 usertalks have been registered.
# 777 usertalks have been registered.
# 778 usertalks have been registered.
# 779 usertalks have been registered.
# 780 usertalks have been registered.
# 781 usertalks have been registered.
# 782 usertalks have been registered.
# 783 usertalks have been registered.
# 784 usertalks have been registered.
# 785 usertalks have been registered.
# 786 usertalks have been registered.
# 787 usertalks have been registered.
# 788 usertalks have been registered.
# 789 usertalks have been registered.
# 790 usertalks have been registered.
# 791 usertalks have been registered.
# 792 usertalks have been registered.
# 793 usertalks have been registered.
# 794 usertalks have been registered.
# 795 usertalks have been registered.
# 796 usertalks have been registered.
# 797 usertalks have been registered.
# 798 usertalks have been registered.
# 799 usertalks have been registered.
# 800 usertalks have been registered.
# 801 usertalks have been registered.
# 802 usertalks have been registered.
# 803 usertalks have been registered.
# 804 usertalks have been registered.
# 805 usertalks have been registered.
# 806 usertalks have been registered.
# 807 usertalks have been registered.
# 808 usertalks have been registered.
# 809 usertalks have been registered.
# 810 usertalks have been registered.
# 811 usertalks have been registered.
# 812 usertalks have been registered.
# 813 usertalks have been registered.
# 814 usertalks have been registered.
# 815 usertalks have been registered.
# 816 usertalks have been registered.
# 817 usertalks have been registered.
# 818 usertalks have been registered.
# 819 usertalks have been registered.
# 820 usertalks have been registered.
# 821 usertalks have been registered.
# 822 usertalks have been registered.
# 823 usertalks have been registered.
# 824 usertalks have been registered.
# 825 usertalks have been registered.
# 826 usertalks have been registered.
# 827 usertalks have been registered.
# 828 usertalks have been registered.
# 829 usertalks have been registered.
# 830 usertalks have been registered.
# 831 usertalks have been registered.
# 832 usertalks have been registered.
# 833 usertalks have been registered.
# 834 usertalks have been registered.
# 835 usertalks have been registered.
# 836 usertalks have been registered.
# 837 usertalks have been registered.
# 838 usertalks have been registered.
# 839 usertalks have been registered.
# 840 usertalks have been registered.
# 841 usertalks have been registered.
# 842 usertalks have been registered.
# 843 usertalks have been registered.
# 844 usertalks have been registered.
# 845 usertalks have been registered.
# 846 usertalks have been registered.
# 847 usertalks have been registered.
# 848 usertalks have been registered.
# 849 usertalks have been registered.
# 850 usertalks have been registered.
# 851 usertalks have been registered.
# 852 usertalks have been registered.
# 853 usertalks have been registered.
# 854 usertalks have been registered.
# 855 usertalks have been registered.
# 856 usertalks have been registered.
# 857 usertalks have been registered.
# 858 usertalks have been registered.
# 859 usertalks have been registered.
# 860 usertalks have been registered.
# 861 usertalks have been registered.
# 862 usertalks have been registered.
# 863 usertalks have been registered.
# 864 usertalks have been registered.
# 865 usertalks have been registered.
# 866 usertalks have been registered.
# 867 usertalks have been registered.
# 868 usertalks have been registered.
# 869 usertalks have been registered.
# 870 usertalks have been registered.
# 871 usertalks have been registered.
# 872 usertalks have been registered.
# 873 usertalks have been registered.
# 874 usertalks have been registered.
# 875 usertalks have been registered.
# 876 usertalks have been registered.
# 877 usertalks have been registered.
# 878 usertalks have been registered.
# 879 usertalks have been registered.
# 880 usertalks have been registered.
# 881 usertalks have been registered.
# 882 usertalks have been registered.
# 883 usertalks have been registered.
# 884 usertalks have been registered.
# 885 usertalks have been registered.
# 886 usertalks have been registered.
# 887 usertalks have been registered.
# 888 usertalks have been registered.
# 889 usertalks have been registered.
# 890 usertalks have been registered.
# 891 usertalks have been registered.
# 892 usertalks have been registered.
# 893 usertalks have been registered.
# 894 usertalks have been registered.
# 895 usertalks have been registered.
# 896 usertalks have been registered.
# 897 usertalks have been registered.
# 898 usertalks have been registered.
# 899 usertalks have been registered.
# 900 usertalks have been registered.
# 901 usertalks have been registered.
# 902 usertalks have been registered.
# 903 usertalks have been registered.
# 904 usertalks have been registered.
# 905 usertalks have been registered.
# 906 usertalks have been registered.
# 907 usertalks have been registered.
# 908 usertalks have been registered.
# 909 usertalks have been registered.
# 910 usertalks have been registered.
# 911 usertalks have been registered.
# 912 usertalks have been registered.
# 913 usertalks have been registered.
# 914 usertalks have been registered.
# 915 usertalks have been registered.
# 916 usertalks have been registered.
# 917 usertalks have been registered.
# 918 usertalks have been registered.
# 919 usertalks have been registered.
# 920 usertalks have been registered.
# 921 usertalks have been registered.
# 922 usertalks have been registered.
# 923 usertalks have been registered.
# 924 usertalks have been registered.
# 925 usertalks have been registered.
# 926 usertalks have been registered.
# 927 usertalks have been registered.
# 928 usertalks have been registered.
# 929 usertalks have been registered.
# 930 usertalks have been registered.
# 931 usertalks have been registered.
# 932 usertalks have been registered.
# 933 usertalks have been registered.
# 934 usertalks have been registered.
# 935 usertalks have been registered.
# 936 usertalks have been registered.
# 937 usertalks have been registered.
# 938 usertalks have been registered.
# 939 usertalks have been registered.
# 940 usertalks have been registered.
# 941 usertalks have been registered.
# 942 usertalks have been registered.
# 943 usertalks have been registered.
# 944 usertalks have been registered.
# 945 usertalks have been registered.
# 946 usertalks have been registered.
# 947 usertalks have been registered.
# 948 usertalks have been registered.
# 949 usertalks have been registered.
# 950 usertalks have been registered.
# 951 usertalks have been registered.
# 952 usertalks have been registered.
# 953 usertalks have been registered.
# 954 usertalks have been registered.
# 955 usertalks have been registered.
# 956 usertalks have been registered.
# 957 usertalks have been registered.
# 958 usertalks have been registered.
# 959 usertalks have been registered.
# 960 usertalks have been registered.
# 961 usertalks have been registered.
# 962 usertalks have been registered.
# 963 usertalks have been registered.
# 964 usertalks have been registered.
# 965 usertalks have been registered.
# 966 usertalks have been registered.
# 967 usertalks have been registered.
# 968 usertalks have been registered.
# 969 usertalks have been registered.
# 970 usertalks have been registered.
# 971 usertalks have been registered.
# 972 usertalks have been registered.
# 973 usertalks have been registered.
# 974 usertalks have been registered.
# 975 usertalks have been registered.
# 976 usertalks have been registered.
# 977 usertalks have been registered.
# 978 usertalks have been registered.
# 979 usertalks have been registered.
# 980 usertalks have been registered.
# 981 usertalks have been registered.
# 982 usertalks have been registered.
# 983 usertalks have been registered.
# 984 usertalks have been registered.
# 985 usertalks have been registered.
# 986 usertalks have been registered.
# 987 usertalks have been registered.
# 988 usertalks have been registered.
# 989 usertalks have been registered.
# 990 usertalks have been registered.
# 991 usertalks have been registered.
# 992 usertalks have been registered.
# 993 usertalks have been registered.
# 994 usertalks have been registered.
# 995 usertalks have been registered.
# 996 usertalks have been registered.
# 997 usertalks have been registered.
# 998 usertalks have been registered.
# 999 usertalks have been registered.
# 1000 usertalks have been registered.
# All wordids have been registered to word_table.
# All synonyms have been registered to synonym_table.
# registered a dict: word_table with file: word_table_data.json
# registered a dict: synonym_table with file: synonym_table_data.json
# Getting usertalks only from dialogue_corpus took about 0.6824848651885986 seconds.
# Making word_table, synonym_table took about 19747.280289411545 seconds.
# Saving word_table, synonym_table took about 0.1581125259399414 seconds.
